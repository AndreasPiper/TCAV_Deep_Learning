# %% [markdown]
# # Running TCAV

# %% [markdown]
# This notebook walks you through an example application of the TCAV library step-by-step to understand which human interpretable concepts (e.g. stripes, dots, zigzags) are important to the image classifier GoogleNet's (a.k.a. Inception v1) prediction of Zebras.

# %% [markdown]
# ## Install required packages
#
# To run through this notebook in the interim, you are encouraged to utilize a `virtualenv` or `conda` environment for installing and working with the required packages to avoid any dependency and compatability issues with different versions of packages.

# %%
# %pip install tensorflow
# %pip install tcav
# Out:
# Requirement already satisfied: tensorflow in c:\users\andre\anaconda3\lib\site-packages (2.10.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: packaging in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: setuptools in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (61.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (22.10.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\andre\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\andre\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\andre\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\andre\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\andre\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.27.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\andre\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\andre\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\andre\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\andre\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\andre\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\andre\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\andre\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\andre\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\andre\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\andre\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\andre\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\andre\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\andre\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Requirement already satisfied: tcav in c:\users\andre\anaconda3\lib\site-packages (0.2.2)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\andre\anaconda3\lib\site-packages (from tcav) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.20.3 in c:\users\andre\anaconda3\lib\site-packages (from tcav) (1.0.2)
# Requirement already satisfied: matplotlib>=2.2.4 in c:\users\andre\anaconda3\lib\site-packages (from tcav) (3.5.1)
# Requirement already satisfied: protobuf>=3.10.0 in c:\users\andre\anaconda3\lib\site-packages (from tcav) (3.19.1)
# Requirement already satisfied: Pillow>=6.0.0 in c:\users\andre\anaconda3\lib\site-packages (from tcav) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\andre\anaconda3\lib\site-packages (from matplotlib>=2.2.4->tcav) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\andre\anaconda3\lib\site-packages (from matplotlib>=2.2.4->tcav) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andre\anaconda3\lib\site-packages (from matplotlib>=2.2.4->tcav) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\andre\anaconda3\lib\site-packages (from matplotlib>=2.2.4->tcav) (3.0.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\andre\anaconda3\lib\site-packages (from matplotlib>=2.2.4->tcav) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\andre\anaconda3\lib\site-packages (from matplotlib>=2.2.4->tcav) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\andre\anaconda3\lib\site-packages (from matplotlib>=2.2.4->tcav) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\andre\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2.4->tcav) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\andre\anaconda3\lib\site-packages (from scikit-learn>=0.20.3->tcav) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\andre\anaconda3\lib\site-packages (from scikit-learn>=0.20.3->tcav) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Download example models and images
#
# Open a terminal and run the following commands:
#
# ```
# cd tcav/tcav_examples/image_models/imagenet
#
# python download_and_make_datasets.py --source_dir=YOUR_PATH --number_of_images_per_folder=50 --number_of_random_folders=3
# ```
#
# This script will download the following content into separate folders into a directory you specify with the `--source_dir=` argument:
#
# **Images**
# *  ImageNet images for the target Zebra class
# *  [Broden dataset](http://netdissect.csail.mit.edu/) images for three concepts (e.g. striped, dotted, zigzagged)
# *  Random ImageNet class images used by TCAV for hypothesis testing of important concepts
#
# **Models**
# *  [Inception 5h model](https://github.com/Hvass-Labs/TensorFlow-Tutorials/blob/master/inception5h.py)
# *  [Mobilenet V2 model](https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet_v1.md)

# %% [markdown]
# ## Import extensions and libraries

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tcav.activation_generator as act_gen
import tcav.cav as cav
import tcav.model  as model
import tcav.tcav as tcav
import tcav.utils as utils
import tcav.utils_plot as utils_plot # utils_plot requires matplotlib
import os 
import tensorflow as tf

# %% [markdown]
# ## TCAV step-by-step
#
# You will walk through the following steps below:
#
# 1. **Store example images in each folder** (you have this if you ran the above)
#  * images for each concept
#  * images for the class/labels of interest
#  * random images that will be negative examples when learning CAVs (images that probably don't belong to any concepts)
# 2. **Write a model wrapper** (below uses example from tcav/model.py)
#  * an instance of  ModelWrapper abstract class (in model.py). This tells TCAV class (tcav.py) how to communicate with your model (e.g., getting internal tensors)
# 3. **Retrieve model activations** (below uses example from tcav/activation_generator.py)
#  * an instance of ActivationGeneratorInterface that tells TCAV class how to load example data and how to get activations from the model
# 4. Run TCAV and visualize scores for important concepts.

# %% [markdown]
# ## Step 1: Store concept and target class images to local folders
#
# ... and tell TCAV where they are.
#
# **source_dir**: where images of concepts, target class and random images (negative samples when learning CAVs) live. Each should be a sub-folder within this directory.
#
# Note that random image directories can be in any name. In this example, we are using `random500_0`, `random500_1`,.. for an arbitrary reason.
#
# You need roughly 50-200 images per concept and target class (10-20 pictures also tend to work, but 200 is pretty safe).
#
#
# **cav_dir**: directory to store CAVs (`None` if you don't want to store)
#
# **target, concept**: names of the target class (that you want to investigate) and concepts (strings) - these are folder names in source_dir
#
# **bottlenecks**: list of bottleneck names (intermediate layers in your model) that you want to use for TCAV. These names are defined in the model wrapper below.

# %%
print ('REMEMBER TO UPDATE YOUR_PATH (where images, models are)!')

# This is the name of your model wrapper (InceptionV3 and GoogleNet are provided in model.py)
model_to_run = 'GoogleNet'  
user = 'andre' #updated
# the name of the parent directory that results are stored (only if you want to cache)
project_name = 'tcav_class_test2'
working_dir = "/tmp/" + user + '/' + project_name
# where activations are stored (only if your act_gen_wrapper does so)
activation_dir =  working_dir+ '/activations/'
# where CAVs are stored. 
# You can say None if you don't wish to store any.
cav_dir = working_dir + '/cavs/'
# where the images live.

# TODO: replace 'YOUR_PATH' with path to downloaded models and images. 
source_dir = "C:/Users/andre/OneDrive/Skrivebord/TCAV_Deep_Learning"
bottlenecks = [ 'mixed4d']  # @param mixed4c

layer_names = ['conv2d0', 'conv2d1', 'conv2d2',
                'mixed3a', 'mixed3b',
                'mixed4a', 'mixed4b', 'mixed4c', 'mixed4d', 'mixed4e',
                'mixed5a', 'mixed5b']
      
utils.make_dir_if_not_exists(activation_dir)
utils.make_dir_if_not_exists(working_dir)
utils.make_dir_if_not_exists(cav_dir)

# this is a regularizer penalty parameter for linear classifier to get CAVs. 
alphas = [0.1]   

target = 'zebra'  
concepts = ["striped"]#, "dotted","zigzagged"]
# Out:
# REMEMBER TO UPDATE YOUR_PATH (where images, models are)!

# %%
import os
os.getcwd()
os.chdir(source_dir)

# %% [markdown]
# ## Step 2: Write your model wrapper
#
# The next step is to tell TCAV how to communicate with your model. See `model.GoogleNetWrapper_public ` for details.
#
# You can define a subclass of ModelWrapper abstract class to do this. Let me walk you thru what each function does (tho they are pretty self-explanatory).  This wrapper includes a lot of the functions that you already have, for example, `get_prediction`.
#
# ### 2.1: Tensors from the graph: bottleneck tensors and ends
# First, store your bottleneck tensors in `self.bottlenecks_tensors` as a dictionary. You only need bottlenecks that you are interested in running TCAV with. Similarly, fill in `self.ends` dictionary with `input`, `logit` and `prediction` tensors.
#
# ### 2.2: Define loss
# Get your loss tensor, and assigned it to `self.loss`. This is what TCAV uses to take directional derivatives.
#
# While doing so, you would also want to set
# ```python
# self.y_input
# ```
# this simply is a tensorflow place holder for the target index in the logit layer (e.g., 0 index for a dog, 1 for a cat).
# For multi-class classification, typically something like this works:
#
# ```python
# self.y_input = tf.placeholder(tf.int64, shape=[None])
# ```
#
# For example, for a multiclass classifier, something like below would work.
#
# ```python
#     # Construct gradient ops.
#     with g.as_default():
#       self.y_input = tf.placeholder(tf.int64, shape=[None])
#
#       self.pred = tf.expand_dims(self.ends['prediction'][0], 0)
#
#       self.loss = tf.reduce_mean(
#           tf.nn.softmax_cross_entropy_with_logits(
#               labels=tf.one_hot(self.y_input, len(self.labels)),
#               logits=self.pred))
#     self._make_gradient_tensors()
# ```
#
# ### 2.3: Call _make_gradient_tensors in __init__() of your wrapper
# ```python
# _make_gradient_tensors()
# ```
# does what you expect - given the loss and bottleneck tensors defined above, it adds gradient tensors.
#
# ### 2.4: Fill in labels, image shapes and a model name.
# Get the mapping from labels (strings) to indice in the logit layer (int) in a dictionary format.
#
# ```python
# def id_to_label(self, idx)
# def label_to_id(self, label)
# ```
#
# Set your input image shape at  `self.image_shape`
#
#
# Set your model name to `self.model_name`
#
# You are done with writing the model wrapper! See the two example model wrapers, InceptionV3 and Googlenet in `tcav/model.py`.

# %%
# Create TensorFlow session.
sess = utils.create_session()

# GRAPH_PATH is where the trained model is stored.
GRAPH_PATH = source_dir + "/pretrained_model/inception5h/tensorflow_inception_graph.pb"
# LABEL_PATH is where the labels are stored. Each line contains one class, and they are ordered with respect to their index in 
# the logit layer. (yes, id_to_label function in the model wrapper reads from this file.)
# For example, imagenet_comp_graph_label_strings.txt looks like:
# dummy                                                                                      
# kit fox
# English setter
# Siberian husky ...

LABEL_PATH = source_dir + "/pretrained_model/inception5h/imagenet_comp_graph_label_strings.txt"

mymodel = model.GoogleNetWrapper_public(sess,
                                        GRAPH_PATH,
                                        LABEL_PATH)
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\tensorflow\python\client\session.py:1769: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %% [markdown]
# ## Step 3: Implement a class that returns activations (maybe with caching!)
#
# Lastly, you will implement a class of the ActivationGenerationInterface which TCAV uses to load example data for a given concept or target, call into your model wrapper and return activations. I pulled out this logic outside of mymodel because this step often takes the longest. By making it modular, you can cache your activations and/or parallelize your computations, as I have done in `ActivationGeneratorBase.process_and_load_activations` in `activation_generator.py`.
#
#
# The `process_and_load_activations` method of the activation generator must return a dictionary of activations that has concept or target name as  a first key, and the bottleneck name as a second key. So something like:
#
# ```python
# {concept1: {bottleneck1: [[0.2, 0.1, ....]]},
# concept2: {bottleneck1: [[0.1, 0.02, ....]]},
# target1: {bottleneck1: [[0.02, 0.99, ....]]}
# ```

# %%
act_generator = act_gen.ImageActivationGenerator(mymodel, source_dir+'/concepts', activation_dir, max_examples=100)

# %% [markdown]
# ## Step 4: Run TCAV and visualize concept importance
#
# You are now ready to run TCAV! Let's do it.
#
# **num_random_exp**: number of experiments to confirm meaningful concept direction. TCAV will search for this many folders named `random500_0`, `random500_1`, etc. You can alternatively set the `random_concepts` keyword to be a list of folders of random concepts. Run at least 10-20 for meaningful tests.
#
# **random_counterpart**: as well as the above, you can optionally supply a single folder with random images as the "positive set" for statistical testing. Reduces computation time at the cost of less reliable random TCAV scores.

# %%
import absl
absl.logging.set_verbosity(0)
num_random_exp=10
## only running num_random_exp = 10 to save some time. The paper number are reported for 500 random runs. 
mytcav = tcav.TCAV(sess,
                   target,
                   concepts,
                   bottlenecks,
                   act_generator,
                   alphas,
                   cav_dir=cav_dir,
                   num_random_exp=num_random_exp)#10)
print ('This may take a while... Go get coffee!')
results = mytcav.run(run_parallel=False)
print ('done!')
# Out:
# INFO:tensorflow:mixed4d ['striped', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['striped', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['striped', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['striped', 'random500_3'] zebra 0.1
# INFO:tensorflow:mixed4d ['striped', 'random500_4'] zebra 0.1
# INFO:tensorflow:mixed4d ['striped', 'random500_5'] zebra 0.1
# INFO:tensorflow:mixed4d ['striped', 'random500_6'] zebra 0.1
# INFO:tensorflow:mixed4d ['striped', 'random500_7'] zebra 0.1
# INFO:tensorflow:mixed4d ['striped', 'random500_8'] zebra 0.1
# INFO:tensorflow:mixed4d ['striped', 'random500_9'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_3'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_4'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_5'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_6'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_7'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_8'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_9'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_3'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_4'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_5'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_6'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_7'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_8'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_9'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_3'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_4'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_5'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_6'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_7'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_8'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_9'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_4'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_5'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_6'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_7'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_8'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_9'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_3'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_5'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_6'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_7'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_8'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_9'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_3'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_4'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_6'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_7'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_8'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_9'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_3'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_4'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_5'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_7'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_8'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_9'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_3'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_4'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_5'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_6'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_8'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_9'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_8', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_8', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_8', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_8', 'random500_3'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_8', 'random500_4'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_8', 'random500_5'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_8', 'random500_6'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_8', 'random500_7'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_8', 'random500_9'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_9', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_9', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_9', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_9', 'random500_3'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_9', 'random500_4'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_9', 'random500_5'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_9', 'random500_6'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_9', 'random500_7'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_9', 'random500_8'] zebra 0.1
# INFO:tensorflow:TCAV will 100 params
# This may take a while... Go get coffee!
# INFO:tensorflow:running 100 params
# INFO:tensorflow:Running param 0 of 100
# INFO:tensorflow:running zebra ['striped', 'random500_0']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_striped_mixed4d shape (100, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:/tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d does not exist, Making one...
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/striped-random500_0-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 1 of 100
# INFO:tensorflow:running zebra ['striped', 'random500_1']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_striped_mixed4d shape (100, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/striped-random500_1-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 2 of 100
# INFO:tensorflow:running zebra ['striped', 'random500_2']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_striped_mixed4d shape (100, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/striped-random500_2-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 0.9655172413793104, 'random500_2': 0.9655172413793104, 'overall': 0.9655172413793104}
# INFO:tensorflow:Running param 3 of 100
# INFO:tensorflow:running zebra ['striped', 'random500_3']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_striped_mixed4d shape (100, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/striped-random500_3-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 0.92, 'random500_3': 1.0, 'overall': 0.9591836734693877}
# INFO:tensorflow:Running param 4 of 100
# INFO:tensorflow:running zebra ['striped', 'random500_4']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_striped_mixed4d shape (100, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/striped-random500_4-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_4': 0.9310344827586207, 'overall': 0.9655172413793104}
# INFO:tensorflow:Running param 5 of 100
# INFO:tensorflow:running zebra ['striped', 'random500_5']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_striped_mixed4d shape (100, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/striped-random500_5-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_5': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 6 of 100
# INFO:tensorflow:running zebra ['striped', 'random500_6']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_striped_mixed4d shape (100, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_6_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/striped-random500_6-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 0.96, 'random500_6': 1.0, 'overall': 0.98}
# INFO:tensorflow:Running param 7 of 100
# INFO:tensorflow:running zebra ['striped', 'random500_7']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_striped_mixed4d shape (100, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/striped-random500_7-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_7': 0.9230769230769231, 'overall': 0.9607843137254902}
# INFO:tensorflow:Running param 8 of 100
# INFO:tensorflow:running zebra ['striped', 'random500_8']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_striped_mixed4d shape (100, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/striped-random500_8-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 0.9166666666666666, 'random500_8': 0.96, 'overall': 0.9387755102040817}
# INFO:tensorflow:Running param 9 of 100
# INFO:tensorflow:running zebra ['striped', 'random500_9']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_striped_mixed4d shape (100, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/striped-random500_9-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 10 of 100
# INFO:tensorflow:running zebra ['random500_0', 'random500_1']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_0-random500_1-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.37037037037037035, 'random500_1': 0.5357142857142857, 'overall': 0.45454545454545453}
# INFO:tensorflow:Running param 11 of 100
# INFO:tensorflow:running zebra ['random500_0', 'random500_2']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_0-random500_2-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.3793103448275862, 'random500_2': 0.3793103448275862, 'overall': 0.3793103448275862}
# INFO:tensorflow:Running param 12 of 100
# INFO:tensorflow:running zebra ['random500_0', 'random500_3']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_0-random500_3-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.56, 'random500_3': 0.4166666666666667, 'overall': 0.4897959183673469}
# INFO:tensorflow:Running param 13 of 100
# INFO:tensorflow:running zebra ['random500_0', 'random500_4']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_0-random500_4-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.6896551724137931, 'random500_4': 0.4827586206896552, 'overall': 0.5862068965517241}
# INFO:tensorflow:Running param 14 of 100
# INFO:tensorflow:running zebra ['random500_0', 'random500_5']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_0-random500_5-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.36, 'random500_5': 0.6, 'overall': 0.48}
# INFO:tensorflow:Running param 15 of 100
# INFO:tensorflow:running zebra ['random500_0', 'random500_6']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_6_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_0-random500_6-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.48, 'random500_6': 0.4, 'overall': 0.44}
# INFO:tensorflow:Running param 16 of 100
# INFO:tensorflow:running zebra ['random500_0', 'random500_7']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_0-random500_7-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.6538461538461539, 'random500_7': 0.6, 'overall': 0.6274509803921569}
# INFO:tensorflow:Running param 17 of 100
# INFO:tensorflow:running zebra ['random500_0', 'random500_8']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_0-random500_8-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.375, 'random500_8': 0.4, 'overall': 0.3877551020408163}
# INFO:tensorflow:Running param 18 of 100
# INFO:tensorflow:running zebra ['random500_0', 'random500_9']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_0-random500_9-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.3333333333333333, 'random500_9': 0.6428571428571429, 'overall': 0.4909090909090909}
# INFO:tensorflow:Running param 19 of 100
# INFO:tensorflow:running zebra ['random500_1', 'random500_0']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_1-random500_0-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.37037037037037035, 'random500_0': 0.6071428571428571, 'overall': 0.4909090909090909}
# INFO:tensorflow:Running param 20 of 100
# INFO:tensorflow:running zebra ['random500_1', 'random500_2']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_1-random500_2-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.5925925925925926, 'random500_2': 0.35714285714285715, 'overall': 0.4727272727272727}
# INFO:tensorflow:Running param 21 of 100
# INFO:tensorflow:running zebra ['random500_1', 'random500_3']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_1-random500_3-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.75, 'random500_3': 0.24, 'overall': 0.4897959183673469}
# INFO:tensorflow:Running param 22 of 100
# INFO:tensorflow:running zebra ['random500_1', 'random500_4']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_1-random500_4-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.4444444444444444, 'random500_4': 0.6785714285714286, 'overall': 0.5636363636363636}
# INFO:tensorflow:Running param 23 of 100
# INFO:tensorflow:running zebra ['random500_1', 'random500_5']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_1-random500_5-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.4, 'random500_5': 0.56, 'overall': 0.48}
# INFO:tensorflow:Running param 24 of 100
# INFO:tensorflow:running zebra ['random500_1', 'random500_6']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_6_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_1-random500_6-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.52, 'random500_6': 0.64, 'overall': 0.58}
# INFO:tensorflow:Running param 25 of 100
# INFO:tensorflow:running zebra ['random500_1', 'random500_7']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_1-random500_7-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.7692307692307693, 'random500_7': 0.24, 'overall': 0.5098039215686274}
# INFO:tensorflow:Running param 26 of 100
# INFO:tensorflow:running zebra ['random500_1', 'random500_8']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_1-random500_8-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.25, 'random500_8': 0.72, 'overall': 0.4897959183673469}
# INFO:tensorflow:Running param 27 of 100
# INFO:tensorflow:running zebra ['random500_1', 'random500_9']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_1-random500_9-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.6071428571428571, 'random500_9': 0.5185185185185185, 'overall': 0.5636363636363636}
# INFO:tensorflow:Running param 28 of 100
# INFO:tensorflow:running zebra ['random500_2', 'random500_0']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_2-random500_0-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.6551724137931034, 'random500_0': 0.3448275862068966, 'overall': 0.5}
# INFO:tensorflow:Running param 29 of 100
# INFO:tensorflow:running zebra ['random500_2', 'random500_1']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_2-random500_1-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.25, 'random500_1': 0.6666666666666666, 'overall': 0.45454545454545453}
# INFO:tensorflow:Running param 30 of 100
# INFO:tensorflow:running zebra ['random500_2', 'random500_3']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_2-random500_3-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.5, 'random500_3': 0.48, 'overall': 0.4897959183673469}
# INFO:tensorflow:Running param 31 of 100
# INFO:tensorflow:running zebra ['random500_2', 'random500_4']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_2-random500_4-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.1724137931034483, 'random500_4': 0.7241379310344828, 'overall': 0.4482758620689655}
# INFO:tensorflow:Running param 32 of 100
# INFO:tensorflow:running zebra ['random500_2', 'random500_5']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_2-random500_5-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.24, 'random500_5': 0.44, 'overall': 0.34}
# INFO:tensorflow:Running param 33 of 100
# INFO:tensorflow:running zebra ['random500_2', 'random500_6']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_6_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_2-random500_6-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.48, 'random500_6': 0.6, 'overall': 0.54}
# INFO:tensorflow:Running param 34 of 100
# INFO:tensorflow:running zebra ['random500_2', 'random500_7']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_2-random500_7-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.4230769230769231, 'random500_7': 0.64, 'overall': 0.5294117647058824}
# INFO:tensorflow:Running param 35 of 100
# INFO:tensorflow:running zebra ['random500_2', 'random500_8']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_2-random500_8-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.5416666666666666, 'random500_8': 0.6, 'overall': 0.5714285714285714}
# INFO:tensorflow:Running param 36 of 100
# INFO:tensorflow:running zebra ['random500_2', 'random500_9']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_2-random500_9-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.5714285714285714, 'random500_9': 0.18518518518518517, 'overall': 0.38181818181818183}
# INFO:tensorflow:Running param 37 of 100
# INFO:tensorflow:running zebra ['random500_3', 'random500_0']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_3-random500_0-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_3': 0.5, 'random500_0': 0.6, 'overall': 0.5510204081632653}
# INFO:tensorflow:Running param 38 of 100
# INFO:tensorflow:running zebra ['random500_3', 'random500_1']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_3-random500_1-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_3': 0.44, 'random500_1': 0.5, 'overall': 0.46938775510204084}
# INFO:tensorflow:Running param 39 of 100
# INFO:tensorflow:running zebra ['random500_3', 'random500_2']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_3-random500_2-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_3': 0.375, 'random500_2': 0.56, 'overall': 0.46938775510204084}
# INFO:tensorflow:Running param 40 of 100
# INFO:tensorflow:running zebra ['random500_3', 'random500_4']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_3-random500_4-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_3': 0.08, 'random500_4': 1.0, 'overall': 0.5306122448979592}
# INFO:tensorflow:Running param 41 of 100
# INFO:tensorflow:running zebra ['random500_3', 'random500_5']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_3-random500_5-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_3': 0.6, 'random500_5': 0.375, 'overall': 0.4897959183673469}
# INFO:tensorflow:Running param 42 of 100
# INFO:tensorflow:running zebra ['random500_3', 'random500_6']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_6_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_3-random500_6-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_3': 0.28, 'random500_6': 0.7916666666666666, 'overall': 0.5306122448979592}
# INFO:tensorflow:Running param 43 of 100
# INFO:tensorflow:running zebra ['random500_3', 'random500_7']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_3-random500_7-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_3': 0.48, 'random500_7': 0.625, 'overall': 0.5510204081632653}
# INFO:tensorflow:Running param 44 of 100
# INFO:tensorflow:running zebra ['random500_3', 'random500_8']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_3-random500_8-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_3': 0.3333333333333333, 'random500_8': 0.4, 'overall': 0.3673469387755102}
# INFO:tensorflow:Running param 45 of 100
# INFO:tensorflow:running zebra ['random500_3', 'random500_9']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_3-random500_9-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_3': 0.48, 'random500_9': 0.75, 'overall': 0.6122448979591837}
# INFO:tensorflow:Running param 46 of 100
# INFO:tensorflow:running zebra ['random500_4', 'random500_0']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_4-random500_0-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_4': 0.4827586206896552, 'random500_0': 0.5517241379310345, 'overall': 0.5172413793103449}
# INFO:tensorflow:Running param 47 of 100
# INFO:tensorflow:running zebra ['random500_4', 'random500_1']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_4-random500_1-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_4': 0.8148148148148148, 'random500_1': 0.39285714285714285, 'overall': 0.6}
# INFO:tensorflow:Running param 48 of 100
# INFO:tensorflow:running zebra ['random500_4', 'random500_2']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_4-random500_2-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_4': 0.4482758620689655, 'random500_2': 0.5172413793103449, 'overall': 0.4827586206896552}
# INFO:tensorflow:Running param 49 of 100
# INFO:tensorflow:running zebra ['random500_4', 'random500_3']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_4-random500_3-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_4': 0.36, 'random500_3': 0.7916666666666666, 'overall': 0.5714285714285714}
# INFO:tensorflow:Running param 50 of 100
# INFO:tensorflow:running zebra ['random500_4', 'random500_5']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_4-random500_5-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_4': 0.32, 'random500_5': 0.52, 'overall': 0.42}
# INFO:tensorflow:Running param 51 of 100
# INFO:tensorflow:running zebra ['random500_4', 'random500_6']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_6_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_4-random500_6-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_4': 0.48, 'random500_6': 0.8, 'overall': 0.64}
# INFO:tensorflow:Running param 52 of 100
# INFO:tensorflow:running zebra ['random500_4', 'random500_7']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_4-random500_7-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_4': 0.5384615384615384, 'random500_7': 0.6, 'overall': 0.5686274509803921}
# INFO:tensorflow:Running param 53 of 100
# INFO:tensorflow:running zebra ['random500_4', 'random500_8']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_4-random500_8-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_4': 0.48, 'random500_8': 0.5833333333333334, 'overall': 0.5306122448979592}
# INFO:tensorflow:Running param 54 of 100
# INFO:tensorflow:running zebra ['random500_4', 'random500_9']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_4-random500_9-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_4': 0.5925925925925926, 'random500_9': 0.42857142857142855, 'overall': 0.509090909090909}
# INFO:tensorflow:Running param 55 of 100
# INFO:tensorflow:running zebra ['random500_5', 'random500_0']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_5-random500_0-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_5': 0.52, 'random500_0': 0.44, 'overall': 0.48}
# INFO:tensorflow:Running param 56 of 100
# INFO:tensorflow:running zebra ['random500_5', 'random500_1']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_5-random500_1-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_5': 0.52, 'random500_1': 0.56, 'overall': 0.54}
# INFO:tensorflow:Running param 57 of 100
# INFO:tensorflow:running zebra ['random500_5', 'random500_2']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_5-random500_2-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_5': 0.36, 'random500_2': 0.68, 'overall': 0.52}
# INFO:tensorflow:Running param 58 of 100
# INFO:tensorflow:running zebra ['random500_5', 'random500_3']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_5-random500_3-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_5': 0.64, 'random500_3': 0.4583333333333333, 'overall': 0.5510204081632653}
# INFO:tensorflow:Running param 59 of 100
# INFO:tensorflow:running zebra ['random500_5', 'random500_4']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_5-random500_4-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_5': 0.88, 'random500_4': 0.16, 'overall': 0.52}
# INFO:tensorflow:Running param 60 of 100
# INFO:tensorflow:running zebra ['random500_5', 'random500_6']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_6_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_5-random500_6-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_5': 0.4, 'random500_6': 0.6, 'overall': 0.5}
# INFO:tensorflow:Running param 61 of 100
# INFO:tensorflow:running zebra ['random500_5', 'random500_7']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_5-random500_7-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_5': 0.2, 'random500_7': 0.68, 'overall': 0.44}
# INFO:tensorflow:Running param 62 of 100
# INFO:tensorflow:running zebra ['random500_5', 'random500_8']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_5-random500_8-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_5': 0.20833333333333334, 'random500_8': 0.64, 'overall': 0.42857142857142855}
# INFO:tensorflow:Running param 63 of 100
# ...
# INFO:tensorflow:Running param 76 of 100
# INFO:tensorflow:running zebra ['random500_7', 'random500_3']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_7-random500_3-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_7': 0.5833333333333334, 'random500_3': 0.6, 'overall': 0.5918367346938775}
# INFO:tensorflow:Running param 77 of 100
# INFO:tensorflow:running zebra ['random500_7', 'random500_4']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_7-random500_4-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_7': 0.48, 'random500_4': 0.6153846153846154, 'overall': 0.5490196078431373}
# INFO:tensorflow:Running param 78 of 100
# INFO:tensorflow:running zebra ['random500_7', 'random500_5']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_7-random500_5-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_7': 0.36, 'random500_5': 0.68, 'overall': 0.52}
# INFO:tensorflow:Running param 79 of 100
# INFO:tensorflow:running zebra ['random500_7', 'random500_6']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_6_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_7-random500_6-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_7': 0.72, 'random500_6': 0.44, 'overall': 0.58}
# INFO:tensorflow:Running param 80 of 100
# INFO:tensorflow:running zebra ['random500_7', 'random500_8']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_7-random500_8-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_7': 0.64, 'random500_8': 0.5, 'overall': 0.5714285714285714}
# INFO:tensorflow:Running param 81 of 100
# INFO:tensorflow:running zebra ['random500_7', 'random500_9']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_7-random500_9-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_7': 0.3076923076923077, 'random500_9': 0.48, 'overall': 0.39215686274509803}
# INFO:tensorflow:Running param 82 of 100
# INFO:tensorflow:running zebra ['random500_8', 'random500_0']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_8-random500_0-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.32, 'random500_0': 0.5416666666666666, 'overall': 0.42857142857142855}
# INFO:tensorflow:Running param 83 of 100
# INFO:tensorflow:running zebra ['random500_8', 'random500_1']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_8-random500_1-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.6666666666666666, 'random500_1': 0.28, 'overall': 0.46938775510204084}
# INFO:tensorflow:Running param 84 of 100
# INFO:tensorflow:running zebra ['random500_8', 'random500_2']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_8-random500_2-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.5416666666666666, 'random500_2': 0.36, 'overall': 0.4489795918367347}
# INFO:tensorflow:Running param 85 of 100
# INFO:tensorflow:running zebra ['random500_8', 'random500_3']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_8-random500_3-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.52, 'random500_3': 0.5, 'overall': 0.5102040816326531}
# INFO:tensorflow:Running param 86 of 100
# INFO:tensorflow:running zebra ['random500_8', 'random500_4']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_8-random500_4-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.28, 'random500_4': 0.7083333333333334, 'overall': 0.4897959183673469}
# INFO:tensorflow:Running param 87 of 100
# INFO:tensorflow:running zebra ['random500_8', 'random500_5']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_8-random500_5-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.041666666666666664, 'random500_5': 0.84, 'overall': 0.4489795918367347}
# INFO:tensorflow:Running param 88 of 100
# INFO:tensorflow:running zebra ['random500_8', 'random500_6']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_6_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_8-random500_6-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.6666666666666666, 'random500_6': 0.44, 'overall': 0.5510204081632653}
# INFO:tensorflow:Running param 89 of 100
# INFO:tensorflow:running zebra ['random500_8', 'random500_7']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_8-random500_7-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.68, 'random500_7': 0.5, 'overall': 0.5918367346938775}
# INFO:tensorflow:Running param 90 of 100
# INFO:tensorflow:running zebra ['random500_8', 'random500_9']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_8-random500_9-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.5, 'random500_9': 0.64, 'overall': 0.5714285714285714}
# INFO:tensorflow:Running param 91 of 100
# INFO:tensorflow:running zebra ['random500_9', 'random500_0']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_0_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_9-random500_0-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.42857142857142855, 'random500_0': 0.5185185185185185, 'overall': 0.4727272727272727}
# INFO:tensorflow:Running param 92 of 100
# INFO:tensorflow:running zebra ['random500_9', 'random500_1']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_1_mixed4d shape (82, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_9-random500_1-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.7407407407407407, 'random500_1': 0.25, 'overall': 0.4909090909090909}
# INFO:tensorflow:Running param 93 of 100
# INFO:tensorflow:running zebra ['random500_9', 'random500_2']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_2_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_9-random500_2-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.35714285714285715, 'random500_2': 0.7037037037037037, 'overall': 0.5272727272727272}
# INFO:tensorflow:Running param 94 of 100
# INFO:tensorflow:running zebra ['random500_9', 'random500_3']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_3_mixed4d shape (73, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_9-random500_3-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.6666666666666666, 'random500_3': 0.48, 'overall': 0.5714285714285714}
# INFO:tensorflow:Running param 95 of 100
# INFO:tensorflow:running zebra ['random500_9', 'random500_4']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_4_mixed4d shape (87, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_9-random500_4-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.7037037037037037, 'random500_4': 0.39285714285714285, 'overall': 0.5454545454545454}
# INFO:tensorflow:Running param 96 of 100
# INFO:tensorflow:running zebra ['random500_9', 'random500_5']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_5_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_9-random500_5-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.56, 'random500_5': 0.28, 'overall': 0.4200000000000001}
# INFO:tensorflow:Running param 97 of 100
# INFO:tensorflow:running zebra ['random500_9', 'random500_6']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_6_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_9-random500_6-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.4, 'random500_6': 0.4, 'overall': 0.4}
# INFO:tensorflow:Running param 98 of 100
# INFO:tensorflow:running zebra ['random500_9', 'random500_7']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_7_mixed4d shape (76, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_9-random500_7-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.64, 'random500_7': 0.2692307692307692, 'overall': 0.45098039215686275}
# INFO:tensorflow:Running param 99 of 100
# INFO:tensorflow:running zebra ['random500_9', 'random500_8']
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_9_mixed4d shape (83, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_random500_8_mixed4d shape (74, 14, 14, 528)
# INFO:tensorflow:Loaded /tmp/andre/tcav_class_test2/activations/acts_zebra_mixed4d shape (75, 14, 14, 528)
# INFO:tensorflow:CAV already exists: /tmp/andre/tcav_class_test2/cavs/random500_9-random500_8-mixed4d-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.72, 'random500_8': 0.125, 'overall': 0.42857142857142855}
# INFO:tensorflow:Done running 100 params. Took 2903.9546296596527 seconds...
# done!

# %%
utils_plot.plot_results(results, num_random_exp=num_random_exp)
# Out:
# Class = zebra
#   Concept = striped
#     Bottleneck = mixed4d. TCAV Score = 0.92 (+- 0.07), random was 0.49 (+- 0.25). p-val = 0.000 (significant)
# {'mixed4d': {'bn_vals': [0.9226666666666666], 'bn_stds': [0.07125540915139938], 'significant': [True]}}

# %%
import pandas as pd

#List of images:
list_of_zebra = os.listdir(source_dir+'/concepts/zebra')

#Striped - select relevant parameter
temp =[]
for i in range(10):
    temp.append(results[i]['val_directional_dirs'])
    
temp_avg_abs = []
temp_avg = []
for j in range(len(temp[0])):
    avg_img_abs = 0
    avg_img
    for i in range(10):
        avg_img_abs = avg_img_abs + abs(temp[i][j])
        avg_img = avg_img + abs(temp[i][j])
    avg_img_abs = avg_img_abs/10 
    avg_img = avg_img/10 
    
    temp_avg_abs.append(avg_img_abs)
    temp_avg.append(avg_img)
    
dictionary = {'Images':list_of_zebra,'Values':temp_avg, 'Abs': temp_avg_abs}
df = pd.DataFrame(dictionary)
df
# Out:
#                      Images        Values           Abs
# 0         07-07-14-0164.jpg  7.695490e-06  3.319293e-06
# 1              100_0784.jpg  3.010617e-04  3.002922e-04
# 2              100_1837.jpg  3.063640e-05  5.302284e-07
# 3              100_3757.jpg  3.909085e-06  8.454453e-07
# 4             122-Zebra.jpg  4.787531e-07  8.784459e-08
# ..                      ...           ...           ...
# 70      zebra_courtship.jpg  2.824738e-05  1.920558e-05
# 71       Zebra_de_Grevy.jpg  7.094389e-04  7.066142e-04
# 72          Zebra_klein.jpg  7.516094e-05  4.217049e-06
# 73  zebra_knp-0265_blog.jpg  5.127806e-05  4.376197e-05
# 74     zebra_lznp-r0167.jpg  3.161380e-02  3.160867e-02
#
# [75 rows x 3 columns]

# %%
df.sort_values(by="Abs")

# %%
df.sort_values(by="Abs")
# Out:
#                           Images        Values           Abs
# 32                  Dana+076.jpg  4.253860e-05  1.436580e-08
# 4                  122-Zebra.jpg  4.787531e-07  8.784459e-08
# 60             zebra-picture.jpg  2.863006e-04  1.414871e-07
# 57             zebra-002-zoo.jpg  1.177347e-04  1.565755e-07
# 15  800px-Darica_zebra_00816.jpg  2.038968e-04  4.324146e-07
# ..                           ...           ...           ...
# 64                    zebra2.jpg  3.360215e-02  3.359465e-02
# 34                  DSC00279.jpg  3.827249e-02  3.826761e-02
# 46                  IMG_6058.jpg  3.931855e-02  3.904311e-02
# 29                  CIMG3338.jpg  4.163960e-02  4.094975e-02
# 54                 test_1234.jpg  4.560570e-02  4.560324e-02
#
# [75 rows x 3 columns]
