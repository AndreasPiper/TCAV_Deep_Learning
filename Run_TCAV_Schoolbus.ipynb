# %% [markdown]
# # Running TCAV - Schoolbus

# %% [markdown]
# This notebook walks you through an example application of the TCAV library step-by-step to understand which human interpretable concepts (e.g. stripes, dots, zigzags) are important to the image classifier GoogleNet's (a.k.a. Inception v1) prediction of Zebras.

# %% [markdown]
# ## Install required packages
#
# To run through this notebook in the interim, you are encouraged to utilize a `virtualenv` or `conda` environment for installing and working with the required packages to avoid any dependency and compatability issues with different versions of packages.

# %%
#%pip install tensorflow
#%pip install tcav

# %% [markdown]
# ## Download example models and images
#
# Open a terminal and run the following commands:
#
# ```
# cd tcav/tcav_examples/image_models/imagenet
#
# python download_and_make_datasets.py --source_dir=YOUR_PATH --number_of_images_per_folder=50 --number_of_random_folders=3
# ```
#
# This script will download the following content into separate folders into a directory you specify with the `--source_dir=` argument:
#
# **Images**
# *  ImageNet images for the target Zebra class
# *  [Broden dataset](http://netdissect.csail.mit.edu/) images for three concepts (e.g. striped, dotted, zigzagged)
# *  Random ImageNet class images used by TCAV for hypothesis testing of important concepts
#
# **Models**
# *  [Inception 5h model](https://github.com/Hvass-Labs/TensorFlow-Tutorials/blob/master/inception5h.py)
# *  [Mobilenet V2 model](https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet_v1.md)

# %% [markdown]
# ## Import extensions and libraries

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tcav.activation_generator as act_gen
import tcav.cav as cav
import tcav.model  as model
import tcav.tcav as tcav
import tcav.utils as utils
import tcav.utils_plot as utils_plot # utils_plot requires matplotlib
import os 
import tensorflow as tf

# %% [markdown]
# ## TCAV step-by-step
#
# You will walk through the following steps below:
#
# 1. **Store example images in each folder** (you have this if you ran the above)
#  * images for each concept
#  * images for the class/labels of interest
#  * random images that will be negative examples when learning CAVs (images that probably don't belong to any concepts)
# 2. **Write a model wrapper** (below uses example from tcav/model.py)
#  * an instance of  ModelWrapper abstract class (in model.py). This tells TCAV class (tcav.py) how to communicate with your model (e.g., getting internal tensors)
# 3. **Retrieve model activations** (below uses example from tcav/activation_generator.py)
#  * an instance of ActivationGeneratorInterface that tells TCAV class how to load example data and how to get activations from the model
# 4. Run TCAV and visualize scores for important concepts.

# %% [markdown]
# ## Step 1: Store concept and target class images to local folders
#
# ... and tell TCAV where they are.
#
# **source_dir**: where images of concepts, target class and random images (negative samples when learning CAVs) live. Each should be a sub-folder within this directory.
#
# Note that random image directories can be in any name. In this example, we are using `random500_0`, `random500_1`,.. for an arbitrary reason.
#
# You need roughly 50-200 images per concept and target class (10-20 pictures also tend to work, but 200 is pretty safe).
#
#
# **cav_dir**: directory to store CAVs (`None` if you don't want to store)
#
# **target, concept**: names of the target class (that you want to investigate) and concepts (strings) - these are folder names in source_dir
#
# **bottlenecks**: list of bottleneck names (intermediate layers in your model) that you want to use for TCAV. These names are defined in the model wrapper below.

# %%
print ('REMEMBER TO UPDATE YOUR_PATH (where images, models are)!')

# This is the name of your model wrapper (InceptionV3 and GoogleNet are provided in model.py)
model_to_run = 'GoogleNet'  
user = 'beenkim'
# the name of the parent directory that results are stored (only if you want to cache)
project_name = 'tcav_class_test'
working_dir = "/tmp/" + user + '/' + project_name
# where activations are stored (only if your act_gen_wrapper does so)
activation_dir =  working_dir + '/activations/'
# where CAVs are stored. 
# You can say None if you don't wish to store any.
cav_dir = working_dir + '/cavs/'
# where the images live.

# TODO: replace 'YOUR_PATH' with path to downloaded models and images. 
# PIP Directory:
# source_dir = 'C:/Users/andre/Downloads/2_Deep_Learning/tcav/tcav/tcav_examples/image_models/imagenet'
# Julies Directory:
source_dir = 'tcav/tcav_examples\image_models\imagenet'
bottlenecks = [ 'mixed3a','mixed3b','mixed4a', 'mixed4b', 'mixed4c','mixed4d', 'mixed4e', 'mixed5a', 'mixed5b']  # @param 
#bottlenecks = ['mixed5b']

utils.make_dir_if_not_exists(activation_dir)
utils.make_dir_if_not_exists(working_dir)
utils.make_dir_if_not_exists(cav_dir)

# this is a regularizer penalty parameter for linear classifier to get CAVs. 
alphas = [0.1]   

target = 'School bus'  
concepts = ["man","woman", "child"]
# Out:
# REMEMBER TO UPDATE YOUR_PATH (where images, models are)!

# %% [markdown]
# ## Step 2: Write your model wrapper
#
# The next step is to tell TCAV how to communicate with your model. See `model.GoogleNetWrapper_public ` for details.
#
# You can define a subclass of ModelWrapper abstract class to do this. Let me walk you thru what each function does (tho they are pretty self-explanatory).  This wrapper includes a lot of the functions that you already have, for example, `get_prediction`.
#
# ### 2.1: Tensors from the graph: bottleneck tensors and ends
# First, store your bottleneck tensors in `self.bottlenecks_tensors` as a dictionary. You only need bottlenecks that you are interested in running TCAV with. Similarly, fill in `self.ends` dictionary with `input`, `logit` and `prediction` tensors.
#
# ### 2.2: Define loss
# Get your loss tensor, and assigned it to `self.loss`. This is what TCAV uses to take directional derivatives.
#
# While doing so, you would also want to set
# ```python
# self.y_input
# ```
# this simply is a tensorflow place holder for the target index in the logit layer (e.g., 0 index for a dog, 1 for a cat).
# For multi-class classification, typically something like this works:
#
# ```python
# self.y_input = tf.placeholder(tf.int64, shape=[None])
# ```
#
# For example, for a multiclass classifier, something like below would work.
#
# ```python
#     # Construct gradient ops.
#     with g.as_default():
#       self.y_input = tf.placeholder(tf.int64, shape=[None])
#
#       self.pred = tf.expand_dims(self.ends['prediction'][0], 0)
#
#       self.loss = tf.reduce_mean(
#           tf.nn.softmax_cross_entropy_with_logits(
#               labels=tf.one_hot(self.y_input, len(self.labels)),
#               logits=self.pred))
#     self._make_gradient_tensors()
# ```
#
# ### 2.3: Call _make_gradient_tensors in __init__() of your wrapper
# ```python
# _make_gradient_tensors()
# ```
# does what you expect - given the loss and bottleneck tensors defined above, it adds gradient tensors.
#
# ### 2.4: Fill in labels, image shapes and a model name.
# Get the mapping from labels (strings) to indice in the logit layer (int) in a dictionary format.
#
# ```python
# def id_to_label(self, idx)
# def label_to_id(self, label)
# ```
#
# Set your input image shape at  `self.image_shape`
#
#
# Set your model name to `self.model_name`
#
# You are done with writing the model wrapper! See the two example model wrapers, InceptionV3 and Googlenet in `tcav/model.py`.

# %%
# Create TensorFlow session.
sess = utils.create_session()
# GRAPH_PATH is where the trained model is stored.
GRAPH_PATH = source_dir + "/inception5h/tensorflow_inception_graph.pb"

# LABEL_PATH is where the labels are stored. Each line contains one class, and they are ordered with respect to their index in 
# the logit layer. (yes, id_to_label function in the model wrapper reads from this file.)
# For example, imagenet_comp_graph_label_strings.txt looks like:
# dummy                                                                                      
# kit fox
# English setter
# Siberian husky ...

LABEL_PATH = source_dir + "/inception5h/imagenet_comp_graph_label_strings.txt"

mymodel = model.GoogleNetWrapper_public(sess,
                                        GRAPH_PATH,
                                        LABEL_PATH)
# Out:
# c:\Users\julie\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\client\session.py:1769: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %% [markdown]
# ## Step 3: Implement a class that returns activations (maybe with caching!)
#
# Lastly, you will implement a class of the ActivationGenerationInterface which TCAV uses to load example data for a given concept or target, call into your model wrapper and return activations. I pulled out this logic outside of mymodel because this step often takes the longest. By making it modular, you can cache your activations and/or parallelize your computations, as I have done in `ActivationGeneratorBase.process_and_load_activations` in `activation_generator.py`.
#
#
# The `process_and_load_activations` method of the activation generator must return a dictionary of activations that has concept or target name as  a first key, and the bottleneck name as a second key. So something like:
#
# ```python
# {concept1: {bottleneck1: [[0.2, 0.1, ....]]},
# concept2: {bottleneck1: [[0.1, 0.02, ....]]},
# target1: {bottleneck1: [[0.02, 0.99, ....]]}
# ```

# %%
act_generator = act_gen.ImageActivationGenerator(mymodel, source_dir, activation_dir, max_examples=100)

# %% [markdown]
# ## Step 4: Run TCAV and visualize concept importance
#
# You are now ready to run TCAV! Let's do it.
#
# **num_random_exp**: number of experiments to confirm meaningful concept direction. TCAV will search for this many folders named `random500_0`, `random500_1`, etc. You can alternatively set the `random_concepts` keyword to be a list of folders of random concepts. Run at least 10-20 for meaningful tests.
#
# **random_counterpart**: as well as the above, you can optionally supply a single folder with random images as the "positive set" for statistical testing. Reduces computation time at the cost of less reliable random TCAV scores.

# %%
import absl
absl.logging.set_verbosity(0)
num_random_exp=10
## only running num_random_exp = 10 to save some time. The paper number are reported for 500 random runs. 
mytcav = tcav.TCAV(sess,
                   target,
                   concepts,
                   bottlenecks,
                   act_generator,
                   alphas,
                   cav_dir=cav_dir,
                   num_random_exp=num_random_exp) #10)
print ('This may take a while... Go get coffee!')
results = mytcav.run(run_parallel=False)
print ('done!')
# Out:
# INFO:tensorflow:mixed3a ['man', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3a ['man', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3a ['man', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3a ['man', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3a ['man', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3a ['man', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3a ['man', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3a ['man', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3a ['man', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3a ['man', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3a ['woman', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3a ['woman', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3a ['woman', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3a ['woman', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3a ['woman', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3a ['woman', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3a ['woman', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3a ['woman', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3a ['woman', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3a ['woman', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3a ['child', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3a ['child', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3a ['child', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3a ['child', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3a ['child', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3a ['child', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3a ['child', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3a ['child', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3a ['child', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3a ['child', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_0', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_0', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_0', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_0', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_0', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_0', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_0', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_0', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_0', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_1', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_1', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_1', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_1', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_1', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_1', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_1', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_1', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_1', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_2', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_2', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_2', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_2', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_2', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_2', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_2', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_2', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_2', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_3', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_3', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_3', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_3', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_3', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_3', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_3', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_3', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_3', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_4', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_4', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_4', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_4', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_4', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_4', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_4', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_4', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_4', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_5', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_5', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_5', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_5', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_5', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_5', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_5', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_5', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_5', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_6', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_6', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_6', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_6', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_6', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_6', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_6', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_6', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_6', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_7', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_7', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_7', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_7', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_7', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_7', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_7', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_7', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_7', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_8', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_8', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_8', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_8', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_8', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_8', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_8', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_8', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_8', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_9', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_9', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_9', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_9', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_9', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_9', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_9', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_9', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3a ['random500_9', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3b ['man', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3b ['man', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3b ['man', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3b ['man', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3b ['man', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3b ['man', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3b ['man', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3b ['man', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3b ['man', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3b ['man', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3b ['woman', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3b ['woman', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3b ['woman', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3b ['woman', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3b ['woman', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3b ['woman', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3b ['woman', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3b ['woman', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3b ['woman', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3b ['woman', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3b ['child', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3b ['child', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3b ['child', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3b ['child', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3b ['child', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3b ['child', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3b ['child', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3b ['child', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3b ['child', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3b ['child', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_0', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_0', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_0', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_0', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_0', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_0', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_0', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_0', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_0', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_1', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_1', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_1', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_1', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_1', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_1', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_1', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_1', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_1', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_2', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_2', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_2', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_2', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_2', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_2', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_2', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_2', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_2', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_3', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_3', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_3', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_3', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_3', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_3', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_3', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_3', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_3', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_4', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_4', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_4', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_4', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_4', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_4', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_4', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_4', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_4', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_5', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_5', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_5', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_5', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_5', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_5', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_5', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_5', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_5', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_6', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_6', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_6', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_6', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_6', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_6', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_6', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_6', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_6', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_7', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_7', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_7', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_7', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_7', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_7', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_7', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_7', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_7', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_8', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_8', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_8', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_8', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_8', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_8', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_8', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_8', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_8', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_9', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_9', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_9', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_9', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_9', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_9', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_9', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_9', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed3b ['random500_9', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4a ['man', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4a ['man', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4a ['man', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4a ['man', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4a ['man', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4a ['man', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4a ['man', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4a ['man', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4a ['man', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4a ['man', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4a ['woman', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4a ['woman', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4a ['woman', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4a ['woman', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4a ['woman', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4a ['woman', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4a ['woman', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4a ['woman', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4a ['woman', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4a ['woman', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4a ['child', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4a ['child', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4a ['child', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4a ['child', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4a ['child', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4a ['child', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4a ['child', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4a ['child', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4a ['child', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4a ['child', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_0', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_0', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_0', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_0', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_0', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_0', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_0', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_0', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_0', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_1', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_1', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_1', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_1', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_1', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_1', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_1', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_1', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_1', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_2', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_2', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_2', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_2', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_2', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_2', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_2', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_2', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_2', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_3', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_3', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_3', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_3', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_3', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_3', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_3', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_3', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_3', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_4', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_4', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_4', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_4', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_4', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_4', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_4', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_4', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_4', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_5', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_5', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_5', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_5', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_5', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_5', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_5', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_5', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_5', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_6', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_6', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_6', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_6', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_6', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_6', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_6', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_6', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_6', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_7', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_7', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_7', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_7', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_7', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_7', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_7', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_7', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_7', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_8', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_8', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_8', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_8', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_8', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_8', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_8', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_8', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_8', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_9', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_9', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_9', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_9', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_9', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_9', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_9', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_9', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4a ['random500_9', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4b ['man', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4b ['man', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4b ['man', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4b ['man', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4b ['man', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4b ['man', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4b ['man', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4b ['man', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4b ['man', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4b ['man', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4b ['woman', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4b ['woman', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4b ['woman', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4b ['woman', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4b ['woman', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4b ['woman', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4b ['woman', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4b ['woman', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4b ['woman', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4b ['woman', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4b ['child', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4b ['child', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4b ['child', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4b ['child', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4b ['child', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4b ['child', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4b ['child', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4b ['child', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4b ['child', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4b ['child', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_0', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_0', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_0', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_0', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_0', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_0', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_0', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_0', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_0', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_1', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_1', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_1', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_1', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_1', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_1', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_1', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_1', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_1', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_2', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_2', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_2', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_2', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_2', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_2', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_2', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_2', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_2', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_3', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_3', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_3', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_3', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_3', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_3', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_3', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_3', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_3', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_4', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_4', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_4', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_4', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_4', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_4', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_4', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_4', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_4', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_5', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_5', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_5', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_5', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_5', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_5', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_5', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_5', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_5', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_6', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_6', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_6', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_6', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_6', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_6', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_6', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_6', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_6', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_7', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_7', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_7', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_7', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_7', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_7', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_7', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_7', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_7', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_8', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_8', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_8', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_8', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_8', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_8', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_8', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_8', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_8', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_9', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_9', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_9', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_9', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_9', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_9', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_9', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_9', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4b ['random500_9', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4c ['man', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4c ['man', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4c ['man', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4c ['man', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4c ['man', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4c ['man', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4c ['man', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4c ['man', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4c ['man', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4c ['man', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4c ['woman', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4c ['woman', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4c ['woman', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4c ['woman', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4c ['woman', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4c ['woman', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4c ['woman', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4c ['woman', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4c ['woman', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4c ['woman', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4c ['child', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4c ['child', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4c ['child', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4c ['child', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4c ['child', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4c ['child', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4c ['child', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4c ['child', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4c ['child', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4c ['child', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_0', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_0', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_0', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_0', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_0', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_0', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_0', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_0', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_0', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_1', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_1', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_1', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_1', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_1', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_1', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_1', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_1', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_1', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_2', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_2', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_2', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_2', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_2', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_2', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_2', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_2', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_2', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_3', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_3', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_3', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_3', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_3', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_3', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_3', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_3', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_3', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_4', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_4', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_4', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_4', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_4', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_4', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_4', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_4', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_4', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_5', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_5', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_5', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_5', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_5', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_5', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_5', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_5', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_5', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_6', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_6', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_6', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_6', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_6', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_6', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_6', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_6', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_6', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_7', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_7', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_7', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_7', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_7', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_7', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_7', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_7', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_7', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_8', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_8', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_8', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_8', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_8', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_8', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_8', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_8', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_8', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_9', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_9', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_9', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_9', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_9', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_9', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_9', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_9', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4c ['random500_9', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4d ['man', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4d ['man', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4d ['man', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4d ['man', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4d ['man', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4d ['man', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4d ['man', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4d ['man', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4d ['man', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4d ['man', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4d ['woman', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4d ['woman', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4d ['woman', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4d ['woman', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4d ['woman', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4d ['woman', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4d ['woman', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4d ['woman', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4d ['woman', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4d ['woman', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4d ['child', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4d ['child', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4d ['child', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4d ['child', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4d ['child', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4d ['child', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4d ['child', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4d ['child', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4d ['child', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4d ['child', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_3', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_4', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_5', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_7'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_6', 'random500_9'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_0'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_1'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_2'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_3'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_4'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_5'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_6'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_8'] School bus 0.1
# INFO:tensorflow:mixed4d ['random500_7', 'random500_9'] School bus 0.1
# ...
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_7-random500_3-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_7': 0.625, 'random500_3': 0.7916666666666666, 'overall': 0.7083333333333334}
# INFO:tensorflow:Running param 1057 of 1080
# INFO:tensorflow:running School bus ['random500_7', 'random500_4']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_7_mixed5b shape (76, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_4_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_7-random500_4-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_7': 0.5769230769230769, 'random500_4': 0.4, 'overall': 0.49019607843137253}
# INFO:tensorflow:Running param 1058 of 1080
# INFO:tensorflow:running School bus ['random500_7', 'random500_5']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_7_mixed5b shape (76, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_5_mixed5b shape (75, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_7-random500_5-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_7': 0.4, 'random500_5': 0.24, 'overall': 0.32}
# INFO:tensorflow:Running param 1059 of 1080
# INFO:tensorflow:running School bus ['random500_7', 'random500_6']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_7_mixed5b shape (76, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_6_mixed5b shape (75, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_7-random500_6-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_7': 0.48, 'random500_6': 0.48, 'overall': 0.48}
# INFO:tensorflow:Running param 1060 of 1080
# INFO:tensorflow:running School bus ['random500_7', 'random500_8']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_7_mixed5b shape (76, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_8_mixed5b shape (74, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_7-random500_8-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_7': 0.75, 'random500_8': 0.4, 'overall': 0.5714285714285714}
# INFO:tensorflow:Running param 1061 of 1080
# INFO:tensorflow:running School bus ['random500_7', 'random500_9']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_7_mixed5b shape (76, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_9_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_7-random500_9-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_7': 0.8, 'random500_9': 0.3076923076923077, 'overall': 0.5490196078431373}
# INFO:tensorflow:Running param 1062 of 1080
# INFO:tensorflow:running School bus ['random500_8', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_8_mixed5b shape (74, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_8-random500_0-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.76, 'random500_0': 0.4583333333333333, 'overall': 0.6122448979591837}
# INFO:tensorflow:Running param 1063 of 1080
# INFO:tensorflow:running School bus ['random500_8', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_8_mixed5b shape (74, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_8-random500_1-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.16666666666666666, 'random500_1': 0.68, 'overall': 0.42857142857142855}
# INFO:tensorflow:Running param 1064 of 1080
# INFO:tensorflow:running School bus ['random500_8', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_8_mixed5b shape (74, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_8-random500_2-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.56, 'random500_2': 0.4166666666666667, 'overall': 0.4897959183673469}
# INFO:tensorflow:Running param 1065 of 1080
# INFO:tensorflow:running School bus ['random500_8', 'random500_3']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_8_mixed5b shape (74, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_3_mixed5b shape (72, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_8-random500_3-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.5416666666666666, 'random500_3': 0.6666666666666666, 'overall': 0.6041666666666666}
# INFO:tensorflow:Running param 1066 of 1080
# INFO:tensorflow:running School bus ['random500_8', 'random500_4']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_8_mixed5b shape (74, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_4_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_8-random500_4-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.75, 'random500_4': 0.56, 'overall': 0.6530612244897959}
# INFO:tensorflow:Running param 1067 of 1080
# INFO:tensorflow:running School bus ['random500_8', 'random500_5']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_8_mixed5b shape (74, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_5_mixed5b shape (75, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_8-random500_5-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.8, 'random500_5': 0.125, 'overall': 0.46938775510204084}
# INFO:tensorflow:Running param 1068 of 1080
# INFO:tensorflow:running School bus ['random500_8', 'random500_6']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_8_mixed5b shape (74, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_6_mixed5b shape (75, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_8-random500_6-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.44, 'random500_6': 0.75, 'overall': 0.5918367346938775}
# INFO:tensorflow:Running param 1069 of 1080
# INFO:tensorflow:running School bus ['random500_8', 'random500_7']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_8_mixed5b shape (74, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_7_mixed5b shape (76, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_8-random500_7-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.76, 'random500_7': 0.4166666666666667, 'overall': 0.5918367346938775}
# INFO:tensorflow:Running param 1070 of 1080
# INFO:tensorflow:running School bus ['random500_8', 'random500_9']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_8_mixed5b shape (74, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_9_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_8-random500_9-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_8': 0.2, 'random500_9': 0.8333333333333334, 'overall': 0.5102040816326531}
# INFO:tensorflow:Running param 1071 of 1080
# INFO:tensorflow:running School bus ['random500_9', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_9_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_9-random500_0-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.5555555555555556, 'random500_0': 0.6071428571428571, 'overall': 0.5818181818181818}
# INFO:tensorflow:Running param 1072 of 1080
# INFO:tensorflow:running School bus ['random500_9', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_9_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_9-random500_1-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.6296296296296297, 'random500_1': 0.32142857142857145, 'overall': 0.4727272727272727}
# INFO:tensorflow:Running param 1073 of 1080
# INFO:tensorflow:running School bus ['random500_9', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_9_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_9-random500_2-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.4444444444444444, 'random500_2': 0.6428571428571429, 'overall': 0.5454545454545454}
# INFO:tensorflow:Running param 1074 of 1080
# INFO:tensorflow:running School bus ['random500_9', 'random500_3']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_9_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_3_mixed5b shape (72, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_9-random500_3-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.7083333333333334, 'random500_3': 0.5, 'overall': 0.6041666666666666}
# INFO:tensorflow:Running param 1075 of 1080
# INFO:tensorflow:running School bus ['random500_9', 'random500_4']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_9_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_4_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_9-random500_4-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.39285714285714285, 'random500_4': 0.6296296296296297, 'overall': 0.509090909090909}
# INFO:tensorflow:Running param 1076 of 1080
# INFO:tensorflow:running School bus ['random500_9', 'random500_5']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_9_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_5_mixed5b shape (75, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_9-random500_5-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.6, 'random500_5': 0.36, 'overall': 0.48}
# INFO:tensorflow:Running param 1077 of 1080
# INFO:tensorflow:running School bus ['random500_9', 'random500_6']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_9_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_6_mixed5b shape (75, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_9-random500_6-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.6, 'random500_6': 0.24, 'overall': 0.42}
# INFO:tensorflow:Running param 1078 of 1080
# INFO:tensorflow:running School bus ['random500_9', 'random500_7']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_9_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_7_mixed5b shape (76, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_9-random500_7-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.6923076923076923, 'random500_7': 0.44, 'overall': 0.5686274509803921}
# INFO:tensorflow:Running param 1079 of 1080
# INFO:tensorflow:running School bus ['random500_9', 'random500_8']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_9_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_8_mixed5b shape (74, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_School bus_mixed5b shape (58, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_9-random500_8-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_9': 0.625, 'random500_8': 0.44, 'overall': 0.5306122448979592}
# INFO:tensorflow:Done running 1080 params. Took 10813.3146879673 seconds...
# done!

# %% [markdown]
# > Save the results in a json file (takes around 30min. to run a layer)

# %%
# import json
# with open(bottlenecks[0], 'w') as json_file:
#     json.dump(results, json_file)

import json
with open('Schoolbus_all_layers', 'w') as json_file:
    json.dump(results, json_file)

# %%
utils_plot.plot_results(results, num_random_exp=num_random_exp)
# Out:
# Class = School bus
#   Concept = man
#     Bottleneck = mixed3a. TCAV Score = 0.41 (+- 0.15), random was 0.50 (+- 0.17). p-val = 0.111 (not significant)
#     Bottleneck = mixed3b. TCAV Score = 0.31 (+- 0.16), random was 0.52 (+- 0.19). p-val = 0.001 (significant)
#     Bottleneck = mixed4a. TCAV Score = 0.18 (+- 0.10), random was 0.50 (+- 0.21). p-val = 0.000 (significant)
#     Bottleneck = mixed4b. TCAV Score = 0.27 (+- 0.18), random was 0.51 (+- 0.22). p-val = 0.001 (significant)
#     Bottleneck = mixed4c. TCAV Score = 0.32 (+- 0.20), random was 0.49 (+- 0.25). p-val = 0.044 (significant)
#     Bottleneck = mixed4d. TCAV Score = 0.43 (+- 0.24), random was 0.51 (+- 0.28). p-val = 0.410 (not significant)
#     Bottleneck = mixed4e. TCAV Score = 0.18 (+- 0.15), random was 0.51 (+- 0.27). p-val = 0.000 (significant)
#     Bottleneck = mixed5a. TCAV Score = 0.30 (+- 0.22), random was 0.52 (+- 0.29). p-val = 0.023 (significant)
#     Bottleneck = mixed5b. TCAV Score = 0.47 (+- 0.27), random was 0.53 (+- 0.35). p-val = 0.604 (not significant)
#   Concept = woman
#     Bottleneck = mixed3a. TCAV Score = 0.47 (+- 0.10), random was 0.50 (+- 0.17). p-val = 0.547 (not significant)
#     Bottleneck = mixed3b. TCAV Score = 0.49 (+- 0.14), random was 0.52 (+- 0.19). p-val = 0.633 (not significant)
#     Bottleneck = mixed4a. TCAV Score = 0.29 (+- 0.14), random was 0.50 (+- 0.21). p-val = 0.003 (significant)
#     Bottleneck = mixed4b. TCAV Score = 0.40 (+- 0.22), random was 0.51 (+- 0.22). p-val = 0.150 (not significant)
#     Bottleneck = mixed4c. TCAV Score = 0.41 (+- 0.19), random was 0.49 (+- 0.25). p-val = 0.331 (not significant)
#     Bottleneck = mixed4d. TCAV Score = 0.54 (+- 0.24), random was 0.51 (+- 0.28). p-val = 0.705 (not significant)
#     Bottleneck = mixed4e. TCAV Score = 0.35 (+- 0.24), random was 0.51 (+- 0.27). p-val = 0.072 (not significant)
#     Bottleneck = mixed5a. TCAV Score = 0.25 (+- 0.15), random was 0.52 (+- 0.29). p-val = 0.005 (significant)
#     Bottleneck = mixed5b. TCAV Score = 0.04 (+- 0.03), random was 0.53 (+- 0.35). p-val = 0.000 (significant)
#   Concept = child
#     Bottleneck = mixed3a. TCAV Score = 0.29 (+- 0.15), random was 0.50 (+- 0.17). p-val = 0.000 (significant)
#     Bottleneck = mixed3b. TCAV Score = 0.20 (+- 0.09), random was 0.52 (+- 0.19). p-val = 0.000 (significant)
#     Bottleneck = mixed4a. TCAV Score = 0.11 (+- 0.09), random was 0.50 (+- 0.21). p-val = 0.000 (significant)
#     Bottleneck = mixed4b. TCAV Score = 0.14 (+- 0.12), random was 0.51 (+- 0.22). p-val = 0.000 (significant)
#     Bottleneck = mixed4c. TCAV Score = 0.20 (+- 0.12), random was 0.49 (+- 0.25). p-val = 0.001 (significant)
#     Bottleneck = mixed4d. TCAV Score = 0.26 (+- 0.18), random was 0.51 (+- 0.28). p-val = 0.008 (significant)
#     Bottleneck = mixed4e. TCAV Score = 0.06 (+- 0.04), random was 0.51 (+- 0.27). p-val = 0.000 (significant)
#     Bottleneck = mixed5a. TCAV Score = 0.20 (+- 0.16), random was 0.52 (+- 0.29). p-val = 0.001 (significant)
#     Bottleneck = mixed5b. TCAV Score = 0.05 (+- 0.02), random was 0.53 (+- 0.35). p-val = 0.000 (significant)
# {'mixed3a': {'bn_vals': [0.01, 0.01, 0.29137931034482756], 'bn_stds': [0, 0, 0.1544908403058468], 'significant': [False, False, True]}, 'mixed3b': {'bn_vals': [0.3120689655172414, 0.01, 0.19655172413793104], 'bn_stds': [0.15640316511967728, 0, 0.09194683879981644], 'significant': [True, False, True]}, 'mixed4a': {'bn_vals': [0.18275862068965515, 0.2862068965517242, 0.10862068965517242], 'bn_stds': [0.09970229168828247, 0.13926083107799087, 0.0947648695424917], 'significant': [True, True, True]}, 'mixed4b': {'bn_vals': [0.26724137931034486, 0.01, 0.1396551724137931], 'bn_stds': [0.17855444118282743, 0, 0.11981208036614958], 'significant': [True, False, True]}, 'mixed4c': {'bn_vals': [0.31724137931034485, 0.01, 0.20344827586206896], 'bn_stds': [0.20153985098210284, 0, 0.11713991552733123], 'significant': [True, False, True]}, 'mixed4d': {'bn_vals': [0.01, 0.01, 0.2620689655172414], 'bn_stds': [0, 0, 0.18178007383582345], 'significant': [False, False, True]}, 'mixed4e': {'bn_vals': [0.1810344827586207, 0.01, 0.06034482758620689], 'bn_stds': [0.15134160240433406, 0, 0.043103448275862065], 'significant': [True, False, True]}, 'mixed5a': {'bn_vals': [0.30000000000000004, 0.2482758620689655, 0.20344827586206896], 'bn_stds': [0.21743286579909582, 0.15386421736084901, 0.15570788834311225], 'significant': [True, True, True]}, 'mixed5b': {'bn_vals': [0.01, 0.03620689655172414, 0.04655172413793103], 'bn_stds': [0, 0.030307579019391285, 0.020473003598341234], 'significant': [False, True, True]}}
