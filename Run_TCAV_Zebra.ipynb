# %% [markdown]
# # Running TCAV

# %% [markdown]
# This notebook walks you through an example application of the TCAV library step-by-step to understand which human interpretable concepts (e.g. stripes, dots, zigzags) are important to the image classifier GoogleNet's (a.k.a. Inception v1) prediction of Zebras.

# %% [markdown]
# ## Install required packages
#
# To run through this notebook in the interim, you are encouraged to utilize a `virtualenv` or `conda` environment for installing and working with the required packages to avoid any dependency and compatability issues with different versions of packages.

# %%
#%pip install tensorflow
#%pip install tcav

# %% [markdown]
# ## Download example models and images
#
# Open a terminal and run the following commands:
#
# ```
# cd tcav/tcav_examples/image_models/imagenet
#
# python download_and_make_datasets.py --source_dir=YOUR_PATH --number_of_images_per_folder=50 --number_of_random_folders=3
# ```
#
# This script will download the following content into separate folders into a directory you specify with the `--source_dir=` argument:
#
# **Images**
# *  ImageNet images for the target Zebra class
# *  [Broden dataset](http://netdissect.csail.mit.edu/) images for three concepts (e.g. striped, dotted, zigzagged)
# *  Random ImageNet class images used by TCAV for hypothesis testing of important concepts
#
# **Models**
# *  [Inception 5h model](https://github.com/Hvass-Labs/TensorFlow-Tutorials/blob/master/inception5h.py)
# *  [Mobilenet V2 model](https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet_v1.md)

# %% [markdown]
# ## Import extensions and libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tcav.activation_generator as act_gen
import tcav.cav as cav
import tcav.model  as model
import tcav.tcav as tcav
import tcav.utils as utils
import tcav.utils_plot as utils_plot # utils_plot requires matplotlib
import os 
import tensorflow as tf

# %% [markdown]
# ## TCAV step-by-step
#
# You will walk through the following steps below:
#
# 1. **Store example images in each folder** (you have this if you ran the above)
#  * images for each concept
#  * images for the class/labels of interest
#  * random images that will be negative examples when learning CAVs (images that probably don't belong to any concepts)
# 2. **Write a model wrapper** (below uses example from tcav/model.py)
#  * an instance of  ModelWrapper abstract class (in model.py). This tells TCAV class (tcav.py) how to communicate with your model (e.g., getting internal tensors)
# 3. **Retrieve model activations** (below uses example from tcav/activation_generator.py)
#  * an instance of ActivationGeneratorInterface that tells TCAV class how to load example data and how to get activations from the model
# 4. Run TCAV and visualize scores for important concepts.

# %% [markdown]
# ## Step 1: Store concept and target class images to local folders
#
# ... and tell TCAV where they are.
#
# **source_dir**: where images of concepts, target class and random images (negative samples when learning CAVs) live. Each should be a sub-folder within this directory.
#
# Note that random image directories can be in any name. In this example, we are using `random500_0`, `random500_1`,.. for an arbitrary reason.
#
# You need roughly 50-200 images per concept and target class (10-20 pictures also tend to work, but 200 is pretty safe).
#
#
# **cav_dir**: directory to store CAVs (`None` if you don't want to store)
#
# **target, concept**: names of the target class (that you want to investigate) and concepts (strings) - these are folder names in source_dir
#
# **bottlenecks**: list of bottleneck names (intermediate layers in your model) that you want to use for TCAV. These names are defined in the model wrapper below.

# %%
print ('REMEMBER TO UPDATE YOUR_PATH (where images, models are)!')

# This is the name of your model wrapper (InceptionV3 and GoogleNet are provided in model.py)
model_to_run = 'GoogleNet'  
user = 'beenkim'
# the name of the parent directory that results are stored (only if you want to cache)
project_name = 'tcav_class_test'
working_dir = "/tmp/" + user + '/' + project_name
# where activations are stored (only if your act_gen_wrapper does so)
activation_dir =  working_dir + '/activations/'
# where CAVs are stored. 
# You can say None if you don't wish to store any.
cav_dir = working_dir + '/cavs/'
# where the images live.

# TODO: replace 'YOUR_PATH' with path to downloaded models and images. 
# PIP Directory:
# source_dir = 'C:/Users/andre/Downloads/2_Deep_Learning/tcav/tcav/tcav_examples/image_models/imagenet'
# Julies Directory:
source_dir = 'tcav/tcav_examples\image_models\imagenet'
bottlenecks = [ 'mixed3a','mixed3b','mixed4a', 'mixed4b', 'mixed4c','mixed4d', 'mixed4e', 'mixed5a', 'mixed5b']  # @param 
      
utils.make_dir_if_not_exists(activation_dir)
utils.make_dir_if_not_exists(working_dir)
utils.make_dir_if_not_exists(cav_dir)

# this is a regularizer penalty parameter for linear classifier to get CAVs. 
alphas = [0.1]   

target = 'zebra'  
concepts = ["dotted","striped","zigzagged"]
# Out:
# REMEMBER TO UPDATE YOUR_PATH (where images, models are)!

# %% [markdown]
# ## Step 2: Write your model wrapper
#
# The next step is to tell TCAV how to communicate with your model. See `model.GoogleNetWrapper_public ` for details.
#
# You can define a subclass of ModelWrapper abstract class to do this. Let me walk you thru what each function does (tho they are pretty self-explanatory).  This wrapper includes a lot of the functions that you already have, for example, `get_prediction`.
#
# ### 2.1: Tensors from the graph: bottleneck tensors and ends
# First, store your bottleneck tensors in `self.bottlenecks_tensors` as a dictionary. You only need bottlenecks that you are interested in running TCAV with. Similarly, fill in `self.ends` dictionary with `input`, `logit` and `prediction` tensors.
#
# ### 2.2: Define loss
# Get your loss tensor, and assigned it to `self.loss`. This is what TCAV uses to take directional derivatives.
#
# While doing so, you would also want to set
# ```python
# self.y_input
# ```
# this simply is a tensorflow place holder for the target index in the logit layer (e.g., 0 index for a dog, 1 for a cat).
# For multi-class classification, typically something like this works:
#
# ```python
# self.y_input = tf.placeholder(tf.int64, shape=[None])
# ```
#
# For example, for a multiclass classifier, something like below would work.
#
# ```python
#     # Construct gradient ops.
#     with g.as_default():
#       self.y_input = tf.placeholder(tf.int64, shape=[None])
#
#       self.pred = tf.expand_dims(self.ends['prediction'][0], 0)
#
#       self.loss = tf.reduce_mean(
#           tf.nn.softmax_cross_entropy_with_logits(
#               labels=tf.one_hot(self.y_input, len(self.labels)),
#               logits=self.pred))
#     self._make_gradient_tensors()
# ```
#
# ### 2.3: Call _make_gradient_tensors in __init__() of your wrapper
# ```python
# _make_gradient_tensors()
# ```
# does what you expect - given the loss and bottleneck tensors defined above, it adds gradient tensors.
#
# ### 2.4: Fill in labels, image shapes and a model name.
# Get the mapping from labels (strings) to indice in the logit layer (int) in a dictionary format.
#
# ```python
# def id_to_label(self, idx)
# def label_to_id(self, label)
# ```
#
# Set your input image shape at  `self.image_shape`
#
#
# Set your model name to `self.model_name`
#
# You are done with writing the model wrapper! See the two example model wrapers, InceptionV3 and Googlenet in `tcav/model.py`.

# %%
# Create TensorFlow session.
sess = utils.create_session()

# GRAPH_PATH is where the trained model is stored.
GRAPH_PATH = source_dir + "/inception5h/tensorflow_inception_graph.pb"

# LABEL_PATH is where the labels are stored. Each line contains one class, and they are ordered with respect to their index in 
# the logit layer. (yes, id_to_label function in the model wrapper reads from this file.)
# For example, imagenet_comp_graph_label_strings.txt looks like:
# dummy                                                                                      
# kit fox
# English setter
# Siberian husky ...

LABEL_PATH = source_dir + "/inception5h/imagenet_comp_graph_label_strings.txt"

mymodel = model.GoogleNetWrapper_public(sess,
                                        GRAPH_PATH,
                                        LABEL_PATH)

# %% [markdown]
# ## Step 3: Implement a class that returns activations (maybe with caching!)
#
# Lastly, you will implement a class of the ActivationGenerationInterface which TCAV uses to load example data for a given concept or target, call into your model wrapper and return activations. I pulled out this logic outside of mymodel because this step often takes the longest. By making it modular, you can cache your activations and/or parallelize your computations, as I have done in `ActivationGeneratorBase.process_and_load_activations` in `activation_generator.py`.
#
#
# The `process_and_load_activations` method of the activation generator must return a dictionary of activations that has concept or target name as  a first key, and the bottleneck name as a second key. So something like:
#
# ```python
# {concept1: {bottleneck1: [[0.2, 0.1, ....]]},
# concept2: {bottleneck1: [[0.1, 0.02, ....]]},
# target1: {bottleneck1: [[0.02, 0.99, ....]]}
# ```

# %%
act_generator = act_gen.ImageActivationGenerator(mymodel, source_dir, activation_dir, max_examples=100)

# %% [markdown]
# ## Step 4: Run TCAV and visualize concept importance
#
# You are now ready to run TCAV! Let's do it.
#
# **num_random_exp**: number of experiments to confirm meaningful concept direction. TCAV will search for this many folders named `random500_0`, `random500_1`, etc. You can alternatively set the `random_concepts` keyword to be a list of folders of random concepts. Run at least 10-20 for meaningful tests.
#
# **random_counterpart**: as well as the above, you can optionally supply a single folder with random images as the "positive set" for statistical testing. Reduces computation time at the cost of less reliable random TCAV scores.

# %%
import absl
absl.logging.set_verbosity(0)
num_random_exp=3
## only running num_random_exp = 10 to save some time. The paper number are reported for 500 random runs. 
mytcav = tcav.TCAV(sess,
                   target,
                   concepts,
                   bottlenecks,
                   act_generator,
                   alphas,
                   cav_dir=cav_dir,
                   num_random_exp=num_random_exp) #10)
print ('This may take a while... Go get coffee!')
results = mytcav.run(run_parallel=False)
print ('done!')
# Out:
# INFO:tensorflow:mixed3a ['dotted', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed3a ['dotted', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed3a ['dotted', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed3a ['striped', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed3a ['striped', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed3a ['striped', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed3a ['zigzagged', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed3a ['zigzagged', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed3a ['zigzagged', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed3a ['random500_0', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed3a ['random500_0', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed3a ['random500_1', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed3a ['random500_1', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed3a ['random500_2', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed3a ['random500_2', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed3b ['dotted', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed3b ['dotted', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed3b ['dotted', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed3b ['striped', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed3b ['striped', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed3b ['striped', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed3b ['zigzagged', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed3b ['zigzagged', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed3b ['zigzagged', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed3b ['random500_0', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed3b ['random500_0', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed3b ['random500_1', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed3b ['random500_1', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed3b ['random500_2', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed3b ['random500_2', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4a ['dotted', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4a ['dotted', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4a ['dotted', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4a ['striped', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4a ['striped', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4a ['striped', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4a ['zigzagged', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4a ['zigzagged', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4a ['zigzagged', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4a ['random500_0', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4a ['random500_0', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4a ['random500_1', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4a ['random500_1', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4a ['random500_2', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4a ['random500_2', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4b ['dotted', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4b ['dotted', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4b ['dotted', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4b ['striped', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4b ['striped', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4b ['striped', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4b ['zigzagged', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4b ['zigzagged', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4b ['zigzagged', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4b ['random500_0', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4b ['random500_0', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4b ['random500_1', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4b ['random500_1', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4b ['random500_2', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4b ['random500_2', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4c ['dotted', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4c ['dotted', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4c ['dotted', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4c ['striped', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4c ['striped', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4c ['striped', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4c ['zigzagged', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4c ['zigzagged', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4c ['zigzagged', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4c ['random500_0', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4c ['random500_0', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4c ['random500_1', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4c ['random500_1', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4c ['random500_2', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4c ['random500_2', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['dotted', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['dotted', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['dotted', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['striped', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['striped', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['striped', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['zigzagged', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['zigzagged', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['zigzagged', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_0', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_1', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4d ['random500_2', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4e ['dotted', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4e ['dotted', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4e ['dotted', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4e ['striped', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4e ['striped', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4e ['striped', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4e ['zigzagged', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4e ['zigzagged', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4e ['zigzagged', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4e ['random500_0', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed4e ['random500_0', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4e ['random500_1', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4e ['random500_1', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed4e ['random500_2', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed4e ['random500_2', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed5a ['dotted', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed5a ['dotted', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed5a ['dotted', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed5a ['striped', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed5a ['striped', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed5a ['striped', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed5a ['zigzagged', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed5a ['zigzagged', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed5a ['zigzagged', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed5a ['random500_0', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed5a ['random500_0', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed5a ['random500_1', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed5a ['random500_1', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed5a ['random500_2', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed5a ['random500_2', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed5b ['dotted', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed5b ['dotted', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed5b ['dotted', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed5b ['striped', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed5b ['striped', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed5b ['striped', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed5b ['zigzagged', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed5b ['zigzagged', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed5b ['zigzagged', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed5b ['random500_0', 'random500_1'] zebra 0.1
# INFO:tensorflow:mixed5b ['random500_0', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed5b ['random500_1', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed5b ['random500_1', 'random500_2'] zebra 0.1
# INFO:tensorflow:mixed5b ['random500_2', 'random500_0'] zebra 0.1
# INFO:tensorflow:mixed5b ['random500_2', 'random500_1'] zebra 0.1
# INFO:tensorflow:TCAV will 135 params
# This may take a while... Go get coffee!
# INFO:tensorflow:running 135 params
# INFO:tensorflow:Running param 0 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed3a shape (100, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_0-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9310344827586207, 'random500_0': 1.0, 'overall': 0.9655172413793104}
# INFO:tensorflow:Running param 1 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed3a shape (100, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3a shape (82, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_1-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 0.8148148148148148, 'random500_1': 1.0, 'overall': 0.9090909090909091}
# INFO:tensorflow:Running param 2 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed3a shape (100, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_2-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9310344827586207, 'random500_2': 1.0, 'overall': 0.9655172413793104}
# INFO:tensorflow:Running param 3 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed3a shape (100, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_0-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_0': 0.8275862068965517, 'overall': 0.9137931034482759}
# INFO:tensorflow:Running param 4 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed3a shape (100, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3a shape (82, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_1-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 0.8571428571428571, 'random500_1': 1.0, 'overall': 0.9272727272727272}
# INFO:tensorflow:Running param 5 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed3a shape (100, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_2-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 0.9655172413793104, 'random500_2': 1.0, 'overall': 0.9827586206896551}
# INFO:tensorflow:Running param 6 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed3a shape (100, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_0-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 0.9310344827586207, 'random500_0': 1.0, 'overall': 0.9655172413793104}
# INFO:tensorflow:Running param 7 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed3a shape (100, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3a shape (82, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_1-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 0.8888888888888888, 'random500_1': 1.0, 'overall': 0.9454545454545454}
# INFO:tensorflow:Running param 8 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed3a shape (100, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_2-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 0.8620689655172413, 'random500_2': 0.9655172413793104, 'overall': 0.9137931034482759}
# INFO:tensorflow:Running param 9 of 135
# INFO:tensorflow:running zebra ['random500_0', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3a shape (82, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_0-random500_1-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.5714285714285714, 'random500_1': 0.4444444444444444, 'overall': 0.509090909090909}
# INFO:tensorflow:Running param 10 of 135
# INFO:tensorflow:running zebra ['random500_0', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_0-random500_2-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.3793103448275862, 'random500_2': 0.5172413793103449, 'overall': 0.4482758620689655}
# INFO:tensorflow:Running param 11 of 135
# INFO:tensorflow:running zebra ['random500_1', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3a shape (82, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_1-random500_0-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.14814814814814814, 'random500_0': 0.8571428571428571, 'overall': 0.509090909090909}
# INFO:tensorflow:Running param 12 of 135
# INFO:tensorflow:running zebra ['random500_1', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3a shape (82, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_1-random500_2-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.32142857142857145, 'random500_2': 0.5555555555555556, 'overall': 0.43636363636363634}
# INFO:tensorflow:Running param 13 of 135
# INFO:tensorflow:running zebra ['random500_2', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_2-random500_0-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.7586206896551724, 'random500_0': 0.41379310344827586, 'overall': 0.5862068965517241}
# INFO:tensorflow:Running param 14 of 135
# INFO:tensorflow:running zebra ['random500_2', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3a shape (87, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3a shape (82, 28, 28, 256)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3a shape (70, 28, 28, 256)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_2-random500_1-mixed3a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.0, 'random500_1': 0.9642857142857143, 'overall': 0.4909090909090909}
# INFO:tensorflow:Running param 15 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed3b shape (100, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_0-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_0': 0.9310344827586207, 'overall': 0.9655172413793104}
# INFO:tensorflow:Running param 16 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed3b shape (100, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3b shape (82, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_1-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 0.8888888888888888, 'random500_1': 0.9642857142857143, 'overall': 0.9272727272727272}
# INFO:tensorflow:Running param 17 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed3b shape (100, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_2-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_2': 0.9655172413793104, 'overall': 0.9827586206896551}
# INFO:tensorflow:Running param 18 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed3b shape (100, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_0-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 0.896551724137931, 'random500_0': 1.0, 'overall': 0.9482758620689655}
# INFO:tensorflow:Running param 19 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed3b shape (100, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3b shape (82, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_1-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_1': 0.9642857142857143, 'overall': 0.9818181818181818}
# INFO:tensorflow:Running param 20 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed3b shape (100, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_2-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_2': 0.9310344827586207, 'overall': 0.9655172413793104}
# INFO:tensorflow:Running param 21 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed3b shape (100, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_0-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 0.8620689655172413, 'random500_0': 1.0, 'overall': 0.9310344827586207}
# INFO:tensorflow:Running param 22 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed3b shape (100, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3b shape (82, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_1-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 0.9259259259259259, 'random500_1': 0.9642857142857143, 'overall': 0.9454545454545454}
# INFO:tensorflow:Running param 23 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed3b shape (100, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_2-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 0.896551724137931, 'random500_2': 1.0, 'overall': 0.9482758620689655}
# INFO:tensorflow:Running param 24 of 135
# INFO:tensorflow:running zebra ['random500_0', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3b shape (82, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_0-random500_1-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.39285714285714285, 'random500_1': 0.6296296296296297, 'overall': 0.509090909090909}
# INFO:tensorflow:Running param 25 of 135
# INFO:tensorflow:running zebra ['random500_0', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_0-random500_2-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.27586206896551724, 'random500_2': 0.5517241379310345, 'overall': 0.41379310344827586}
# INFO:tensorflow:Running param 26 of 135
# INFO:tensorflow:running zebra ['random500_1', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3b shape (82, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_1-random500_0-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.2962962962962963, 'random500_0': 0.6785714285714286, 'overall': 0.4909090909090909}
# INFO:tensorflow:Running param 27 of 135
# INFO:tensorflow:running zebra ['random500_1', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3b shape (82, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_1-random500_2-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.3333333333333333, 'random500_2': 0.8571428571428571, 'overall': 0.6}
# INFO:tensorflow:Running param 28 of 135
# INFO:tensorflow:running zebra ['random500_2', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_2-random500_0-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.27586206896551724, 'random500_0': 0.41379310344827586, 'overall': 0.3448275862068966}
# INFO:tensorflow:Running param 29 of 135
# INFO:tensorflow:running zebra ['random500_2', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed3b shape (87, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed3b shape (82, 28, 28, 480)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed3b shape (70, 28, 28, 480)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_2-random500_1-mixed3b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.32142857142857145, 'random500_1': 0.6296296296296297, 'overall': 0.4727272727272727}
# INFO:tensorflow:Running param 30 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed4a shape (100, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_0-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_0': 0.9310344827586207, 'overall': 0.9655172413793104}
# INFO:tensorflow:Running param 31 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed4a shape (100, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4a shape (82, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_1-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 32 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed4a shape (100, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_2-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_2': 0.9655172413793104, 'overall': 0.9827586206896551}
# INFO:tensorflow:Running param 33 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed4a shape (100, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_0-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_0': 0.896551724137931, 'overall': 0.9482758620689655}
# INFO:tensorflow:Running param 34 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed4a shape (100, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4a shape (82, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_1-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 0.9629629629629629, 'random500_1': 1.0, 'overall': 0.9818181818181818}
# INFO:tensorflow:Running param 35 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed4a shape (100, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_2-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 0.9655172413793104, 'random500_2': 0.9310344827586207, 'overall': 0.9482758620689655}
# INFO:tensorflow:Running param 36 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed4a shape (100, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_0-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 0.9655172413793104, 'random500_0': 0.9655172413793104, 'overall': 0.9655172413793104}
# INFO:tensorflow:Running param 37 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed4a shape (100, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4a shape (82, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_1-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 38 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed4a shape (100, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_2-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 0.9655172413793104, 'random500_2': 0.896551724137931, 'overall': 0.9310344827586207}
# INFO:tensorflow:Running param 39 of 135
# INFO:tensorflow:running zebra ['random500_0', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4a shape (82, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_0-random500_1-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.4642857142857143, 'random500_1': 0.5555555555555556, 'overall': 0.509090909090909}
# INFO:tensorflow:Running param 40 of 135
# INFO:tensorflow:running zebra ['random500_0', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_0-random500_2-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.3448275862068966, 'random500_2': 0.41379310344827586, 'overall': 0.3793103448275862}
# INFO:tensorflow:Running param 41 of 135
# INFO:tensorflow:running zebra ['random500_1', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4a shape (82, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_1-random500_0-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.42857142857142855, 'random500_0': 0.6296296296296297, 'overall': 0.5272727272727272}
# INFO:tensorflow:Running param 42 of 135
# INFO:tensorflow:running zebra ['random500_1', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4a shape (82, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_1-random500_2-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.6666666666666666, 'random500_2': 0.6785714285714286, 'overall': 0.6727272727272727}
# INFO:tensorflow:Running param 43 of 135
# INFO:tensorflow:running zebra ['random500_2', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_2-random500_0-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.8275862068965517, 'random500_0': 0.1724137931034483, 'overall': 0.5}
# INFO:tensorflow:Running param 44 of 135
# INFO:tensorflow:running zebra ['random500_2', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4a shape (87, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4a shape (82, 14, 14, 508)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4a shape (70, 14, 14, 508)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_2-random500_1-mixed4a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.21428571428571427, 'random500_1': 0.7777777777777778, 'overall': 0.4909090909090909}
# INFO:tensorflow:Running param 45 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed4b shape (100, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_0-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_0': 0.896551724137931, 'overall': 0.9482758620689655}
# INFO:tensorflow:Running param 46 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed4b shape (100, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4b shape (82, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_1-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 47 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed4b shape (100, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_2-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 48 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed4b shape (100, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_0-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 49 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed4b shape (100, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4b shape (82, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_1-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 0.9642857142857143, 'random500_1': 1.0, 'overall': 0.9818181818181818}
# INFO:tensorflow:Running param 50 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed4b shape (100, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_2-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 51 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed4b shape (100, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_0-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 1.0, 'random500_0': 0.9655172413793104, 'overall': 0.9827586206896551}
# INFO:tensorflow:Running param 52 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed4b shape (100, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4b shape (82, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_1-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 0.9642857142857143, 'random500_1': 1.0, 'overall': 0.9818181818181818}
# INFO:tensorflow:Running param 53 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed4b shape (100, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_2-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 54 of 135
# INFO:tensorflow:running zebra ['random500_0', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4b shape (82, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_0-random500_1-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.21428571428571427, 'random500_1': 0.7037037037037037, 'overall': 0.45454545454545453}
# INFO:tensorflow:Running param 55 of 135
# INFO:tensorflow:running zebra ['random500_0', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_0-random500_2-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.3103448275862069, 'random500_2': 0.7931034482758621, 'overall': 0.5517241379310345}
# INFO:tensorflow:Running param 56 of 135
# INFO:tensorflow:running zebra ['random500_1', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4b shape (82, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_1-random500_0-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.6296296296296297, 'random500_0': 0.32142857142857145, 'overall': 0.4727272727272727}
# INFO:tensorflow:Running param 57 of 135
# INFO:tensorflow:running zebra ['random500_1', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed4b shape (82, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_1-random500_2-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.6666666666666666, 'random500_2': 0.25, 'overall': 0.45454545454545453}
# INFO:tensorflow:Running param 58 of 135
# INFO:tensorflow:running zebra ['random500_2', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed4b shape (87, 14, 14, 512)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed4b shape (70, 14, 14, 512)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_2-random500_0-mixed4b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.3103448275862069, 'random500_0': 0.4482758620689655, 'overall': 0.3793103448275862}
# INFO:tensorflow:Running param 59 of 135
# INFO:tensorflow:running zebra ['random500_2', 'random500_1']
# ...
# INFO:tensorflow:Running param 111 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed5a shape (100, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5a shape (87, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5a shape (70, 7, 7, 832)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_0-mixed5a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 0.9310344827586207, 'random500_0': 1.0, 'overall': 0.9655172413793104}
# INFO:tensorflow:Running param 112 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed5a shape (100, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5a shape (82, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5a shape (70, 7, 7, 832)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_1-mixed5a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 113 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed5a shape (100, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5a shape (87, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5a shape (70, 7, 7, 832)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_2-mixed5a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 114 of 135
# INFO:tensorflow:running zebra ['random500_0', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5a shape (87, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5a shape (82, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5a shape (70, 7, 7, 832)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_0-random500_1-mixed5a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.39285714285714285, 'random500_1': 0.6666666666666666, 'overall': 0.5272727272727272}
# INFO:tensorflow:Running param 115 of 135
# INFO:tensorflow:running zebra ['random500_0', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5a shape (87, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5a shape (87, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5a shape (70, 7, 7, 832)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_0-random500_2-mixed5a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.3448275862068966, 'random500_2': 0.7241379310344828, 'overall': 0.5344827586206896}
# INFO:tensorflow:Running param 116 of 135
# INFO:tensorflow:running zebra ['random500_1', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5a shape (82, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5a shape (87, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5a shape (70, 7, 7, 832)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_1-random500_0-mixed5a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.6666666666666666, 'random500_0': 0.21428571428571427, 'overall': 0.43636363636363634}
# INFO:tensorflow:Running param 117 of 135
# INFO:tensorflow:running zebra ['random500_1', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5a shape (82, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5a shape (87, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5a shape (70, 7, 7, 832)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_1-random500_2-mixed5a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.6428571428571429, 'random500_2': 0.3333333333333333, 'overall': 0.4909090909090909}
# INFO:tensorflow:Running param 118 of 135
# INFO:tensorflow:running zebra ['random500_2', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5a shape (87, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5a shape (87, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5a shape (70, 7, 7, 832)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_2-random500_0-mixed5a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.4482758620689655, 'random500_0': 0.5517241379310345, 'overall': 0.5}
# INFO:tensorflow:Running param 119 of 135
# INFO:tensorflow:running zebra ['random500_2', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5a shape (87, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5a shape (82, 7, 7, 832)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5a shape (70, 7, 7, 832)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_2-random500_1-mixed5a-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.32142857142857145, 'random500_1': 0.6296296296296297, 'overall': 0.4727272727272727}
# INFO:tensorflow:Running param 120 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed5b shape (100, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_0-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 121 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed5b shape (100, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_1-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 122 of 135
# INFO:tensorflow:running zebra ['dotted', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_dotted_mixed5b shape (100, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/dotted-random500_2-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_2': 0.9310344827586207, 'overall': 0.9655172413793104}
# INFO:tensorflow:Running param 123 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed5b shape (100, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_0-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_0': 0.9310344827586207, 'overall': 0.9655172413793104}
# INFO:tensorflow:Running param 124 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed5b shape (100, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_1-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_1': 0.9642857142857143, 'overall': 0.9818181818181818}
# INFO:tensorflow:Running param 125 of 135
# INFO:tensorflow:running zebra ['striped', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_striped_mixed5b shape (100, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/striped-random500_2-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_2': 0.9655172413793104, 'overall': 0.9827586206896551}
# INFO:tensorflow:Running param 126 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed5b shape (100, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_0-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 1.0, 'random500_0': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 127 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed5b shape (100, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_1-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 1.0, 'random500_1': 0.9259259259259259, 'overall': 0.9636363636363636}
# INFO:tensorflow:Running param 128 of 135
# INFO:tensorflow:running zebra ['zigzagged', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zigzagged_mixed5b shape (100, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/zigzagged-random500_2-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'zigzagged': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:Running param 129 of 135
# INFO:tensorflow:running zebra ['random500_0', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_0-random500_1-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.25925925925925924, 'random500_1': 0.8571428571428571, 'overall': 0.5636363636363636}
# INFO:tensorflow:Running param 130 of 135
# INFO:tensorflow:running zebra ['random500_0', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_0-random500_2-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_0': 0.6206896551724138, 'random500_2': 0.5172413793103449, 'overall': 0.5689655172413793}
# INFO:tensorflow:Running param 131 of 135
# INFO:tensorflow:running zebra ['random500_1', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_1-random500_0-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.5555555555555556, 'random500_0': 0.5, 'overall': 0.5272727272727272}
# INFO:tensorflow:Running param 132 of 135
# INFO:tensorflow:running zebra ['random500_1', 'random500_2']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_1-random500_2-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_1': 0.5714285714285714, 'random500_2': 0.48148148148148145, 'overall': 0.5272727272727272}
# INFO:tensorflow:Running param 133 of 135
# INFO:tensorflow:running zebra ['random500_2', 'random500_0']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_0_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_2-random500_0-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.4827586206896552, 'random500_0': 0.6551724137931034, 'overall': 0.5689655172413793}
# INFO:tensorflow:Running param 134 of 135
# INFO:tensorflow:running zebra ['random500_2', 'random500_1']
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_2_mixed5b shape (87, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_random500_1_mixed5b shape (82, 7, 7, 1024)
# INFO:tensorflow:Loaded /tmp/beenkim/tcav_class_test/activations/acts_zebra_mixed5b shape (70, 7, 7, 1024)
# INFO:tensorflow:CAV already exists: /tmp/beenkim/tcav_class_test/cavs/random500_2-random500_1-mixed5b-linear-0.1.pkl
# INFO:tensorflow:CAV accuracies: {'random500_2': 0.6666666666666666, 'random500_1': 0.42857142857142855, 'overall': 0.5454545454545454}
# INFO:tensorflow:Done running 135 params. Took 877.3532047271729 seconds...
# done!

# %%
import json
with open('Zebra_all_layers', 'w') as json_file:
    json.dump(results, json_file)

# %%
utils_plot.plot_results(results, num_random_exp=num_random_exp)
# Out:
# Class = zebra
#   Concept = dotted
#     Bottleneck = mixed3a. TCAV Score = 0.33 (+- 0.05), random was 0.51 (+- 0.08). p-val = 0.016 (significant)
#     Bottleneck = mixed3b. TCAV Score = 0.32 (+- 0.10), random was 0.50 (+- 0.12). p-val = 0.079 (not significant)
#     Bottleneck = mixed4a. TCAV Score = 0.17 (+- 0.04), random was 0.56 (+- 0.15). p-val = 0.006 (significant)
#     Bottleneck = mixed4b. TCAV Score = 0.23 (+- 0.05), random was 0.54 (+- 0.14). p-val = 0.013 (significant)
#     Bottleneck = mixed4c. TCAV Score = 0.20 (+- 0.10), random was 0.43 (+- 0.17). p-val = 0.102 (not significant)
#     Bottleneck = mixed4d. TCAV Score = 0.74 (+- 0.10), random was 0.37 (+- 0.26). p-val = 0.074 (not significant)
#     Bottleneck = mixed4e. TCAV Score = 0.73 (+- 0.09), random was 0.49 (+- 0.28). p-val = 0.248 (not significant)
#     Bottleneck = mixed5a. TCAV Score = 0.86 (+- 0.05), random was 0.53 (+- 0.31). p-val = 0.152 (not significant)
#     Bottleneck = mixed5b. TCAV Score = 0.30 (+- 0.35), random was 0.49 (+- 0.29). p-val = 0.466 (not significant)
#   Concept = striped
#     Bottleneck = mixed3a. TCAV Score = 0.51 (+- 0.03), random was 0.51 (+- 0.08). p-val = 1.000 (not significant)
#     Bottleneck = mixed3b. TCAV Score = 0.60 (+- 0.04), random was 0.50 (+- 0.12). p-val = 0.281 (not significant)
#     Bottleneck = mixed4a. TCAV Score = 0.65 (+- 0.08), random was 0.56 (+- 0.15). p-val = 0.436 (not significant)
#     Bottleneck = mixed4b. TCAV Score = 0.79 (+- 0.12), random was 0.54 (+- 0.14). p-val = 0.053 (not significant)
#     Bottleneck = mixed4c. TCAV Score = 0.96 (+- 0.03), random was 0.43 (+- 0.17). p-val = 0.002 (significant)
#     Bottleneck = mixed4d. TCAV Score = 0.93 (+- 0.06), random was 0.37 (+- 0.26). p-val = 0.015 (significant)
#     Bottleneck = mixed4e. TCAV Score = 0.93 (+- 0.07), random was 0.49 (+- 0.28). p-val = 0.052 (not significant)
#     Bottleneck = mixed5a. TCAV Score = 1.00 (+- 0.00), random was 0.53 (+- 0.31). p-val = 0.055 (not significant)
#     Bottleneck = mixed5b. TCAV Score = 1.00 (+- 0.00), random was 0.49 (+- 0.29). p-val = 0.030 (significant)
#   Concept = zigzagged
#     Bottleneck = mixed3a. TCAV Score = 0.39 (+- 0.04), random was 0.51 (+- 0.08). p-val = 0.064 (not significant)
#     Bottleneck = mixed3b. TCAV Score = 0.40 (+- 0.11), random was 0.50 (+- 0.12). p-val = 0.307 (not significant)
#     Bottleneck = mixed4a. TCAV Score = 0.50 (+- 0.05), random was 0.56 (+- 0.15). p-val = 0.613 (not significant)
#     Bottleneck = mixed4b. TCAV Score = 0.70 (+- 0.07), random was 0.54 (+- 0.14). p-val = 0.140 (not significant)
#     Bottleneck = mixed4c. TCAV Score = 0.88 (+- 0.09), random was 0.43 (+- 0.17). p-val = 0.007 (significant)
#     Bottleneck = mixed4d. TCAV Score = 0.75 (+- 0.11), random was 0.37 (+- 0.26). p-val = 0.072 (not significant)
#     Bottleneck = mixed4e. TCAV Score = 0.74 (+- 0.15), random was 0.49 (+- 0.28). p-val = 0.241 (not significant)
#     Bottleneck = mixed5a. TCAV Score = 0.97 (+- 0.02), random was 0.53 (+- 0.31). p-val = 0.071 (not significant)
#     Bottleneck = mixed5b. TCAV Score = 0.70 (+- 0.19), random was 0.49 (+- 0.29). p-val = 0.337 (not significant)
# c:\Users\julie\Documents\DTU\Business Analytics\13_semester\Deep Learning\Final Project data and code\tcav\tcav\utils_plot.py:96: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, p_val = ttest_ind(random_i_ups[bottleneck], i_ups)
# {'mixed3a': {'bn_vals': [0.32857142857142857, 0.01, 0.01], 'bn_stds': [0.05345224838248489, 0, 0], 'significant': [True, False, False]}, 'mixed3b': {'bn_vals': [0.01, 0.01, 0.01], 'bn_stds': [0, 0, 0], 'significant': [False, False, False]}, 'mixed4a': {'bn_vals': [0.16666666666666666, 0.01, 0.01], 'bn_stds': [0.044160088073789065, 0, 0], 'significant': [True, False, False]}, 'mixed4b': {'bn_vals': [0.22857142857142856, 0.01, 0.01], 'bn_stds': [0.05084322977157766, 0, 0], 'significant': [True, False, False]}, 'mixed4c': {'bn_vals': [0.01, 0.9619047619047619, 0.8809523809523809], 'bn_stds': [0, 0.02935435239509035, 0.09060141709733548], 'significant': [False, True, True]}, 'mixed4d': {'bn_vals': [0.01, 0.9285714285714285, 0.01], 'bn_stds': [0, 0.06060915267313264, 0], 'significant': [False, True, False]}, 'mixed4e': {'bn_vals': [0.01, 0.01, 0.01], 'bn_stds': [0, 0, 0], 'significant': [False, False, False]}, 'mixed5a': {'bn_vals': [0.01, 0.01, 0.01], 'bn_stds': [0, 0, 0], 'significant': [False, False, False]}, 'mixed5b': {'bn_vals': [0.01, 1.0, 0.01], 'bn_stds': [0, 0.0, 0], 'significant': [False, True, False]}}
